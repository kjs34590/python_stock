# %% [markdown]
# # 시세 DB 구축 및 시세 조회 API 개발
# ## 01 야후 파이낸스와 네이버 금융 비교하기
# ### 01.1 야후 파이낸스 데이터의 문제점
#
# - 아래는 정리.
# - 코드는 Pycharm으로 시행하기로 한다.

# %%
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()
import matplotlib.pyplot as plt

df = pdr.get_data_yahoo('005930.KS', '2017-01-01')

plt.figure(figsize=(9,6))
plt.subplot(2, 1, 1)
plt.title('Samsung Electronics (Yahoo Finance)')
plt.plot(df.index, df['Close'], 'c', label='Close')
plt.plot(df.index, df['Adj Close'], 'b--', label='Adj Close')
plt.legend(loc='best')
plt.subplot(2, 1, 2)
plt.bar(df.index, df['Volume'], color='g', label='Volume')
plt.legend(loc='best')
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ### 01.2 네이버 금융 데이터로 시세 데이터베이스 구축하기

# %% [markdown]
# - MariaDB 설치하고 pymysql로 버전 확인

# %%
import pymysql

connection = pymysql.connect(host='localhost', port=3306, db='Investar',
                            user='root', passwd='kjs34590', autocommit=True)

cursor = connection.cursor()
cursor.execute("SELECT VERSION();")
result = cursor.fetchone()

print("MariaDB version : {}".format(result))

connection.close()
# Out:
# MariaDB version : ('10.5.12-MariaDB',)

# %% [markdown]
# - DBUpdater 모듈로 네이버 금융의 주식 시세를 매일 자동으로 업데이트하기

# %%
import pandas as pd
from bs4 import BeautifulSoup
import urllib, pymysql, calendar, time, json
from urllib.request import urlopen
from datetime import datetime
from threading import Timer


class DBUpdater:
    def __init__(self):
        """생성자: MariaDB 연결 및 종목코드 딕셔너리 생성"""
        self.conn = pymysql.connect(host='localhost', user='root',
                                    password='kjs34590', db='Investar', charset='utf8')

        with self.conn.cursor() as curs:
            sql = """
            CREATE TABLE IF NOT EXISTS company_info (
                code VARCHAR(20),
                company VARCHAR(40),
                last_update DATE,
                PRIMARY KEY (code))
            """
            curs.execute(sql)
            sql = """
            CREATE TABLE IF NOT EXISTS daily_price (
                code VARCHAR(20),
                date DATE,
                open BIGINT(20),
                high BIGINT(20),
                low BIGINT(20),
                close BIGINT(20),
                diff BIGINT(20),
                volume BIGINT(20),
                PRIMARY KEY (code, date))
            """
            curs.execute(sql)
        self.conn.commit()
        self.codes = dict()

    def __del__(self):
        """소멸자: MariaDB 연결 해제"""
        self.conn.close()

    def read_krx_code(self):
        """KRX로부터 상장기업 목록 파일을 읽어와서 데이터프레임으로 반환"""
        url = 'http://kind.krx.co.kr/corpgeneral/corpList.do?method=' \
              'download&searchType=13'
        krx = pd.read_html(url, header=0)[0]
        krx = krx[['종목코드', '회사명']]
        krx = krx.rename(columns={'종목코드': 'code', '회사명': 'company'})
        krx.code = krx.code.map('{:06d}'.format)
        return krx

    def update_comp_info(self):
        """종목코드를 company_info 테이블에 업데이트 한 후 딕셔너리에 저장"""
        sql = "SELECT * FROM company_info"
        df = pd.read_sql(sql, self.conn)
        for idx in range(len(df)):
            self.codes[df['code'].values[idx]] = df['company'].values[idx]

        with self.conn.cursor() as curs:
            sql = "SELECT max(last_update) FROM company_info"
            curs.execute(sql)
            rs = curs.fetchone()
            today = datetime.today().strftime('%Y-%m-%d')
            if rs[0] == None or rs[0].strftime('%Y-%m-%d') < today:
                krx = self.read_krx_code()
                for idx in range(len(krx)):
                    code = krx.code.values[idx]
                    company = krx.company.values[idx]
                    sql = f"REPLACE INTO company_info (code, company, last"\
                          f"_update) VALUES ('{code}', '{company}', '{today}')"
                    curs.execute(sql)
                    self.codes[code] = company
                    tmnow = datetime.now().strftime('%Y-%m-%d %H:%M')
                    print(f"[{tmnow}] #{idx + 1:04d} REPLACE INTO company_info "\
                          f"VALUES ({code}, {company}, {today})")
                self.conn.commit()
                print('')

    def read_naver(self, code, company, pages_to_fetch):
        """네이버에서 주식 시세를 읽어서 데이터프레임으로 반환"""
        try:
            url = f"http://finance.naver.com/item/sise_day.nhn?code={code}"
            with urlopen(url) as doc:
                if doc is None:
                    return None
                html = BeautifulSoup(doc, "lxml")
                pgrr = html.find("td", class_="pgRR")
                if pgrr is None:
                    return None
                s = str(pgrr.a["href"]).split('=')
                lastpage = s[-1]
            df = pd.DataFrame()
            pages = min(int(lastpage), pages_to_fetch)
            for page in range(1, pages + 1):
                pg_url = '{}&page={}'.format(url, page)
                df = df.append(pd.read_html(requests.get(pg_url, headers={'User-agent': 'Mozilla/5.0'}).text[0]))
                tmnow = datetime.now().strftime('%Y-%m-%d %H:%M')
                print('[{}] {} ({}) : {:04d}/{:04d} pages are downloading...'.
                      format(tmnow, company, code, page, pages), end="\r")
                df = df.rename(columns={'날짜': 'date', '종가': 'close', '전일비': 'diff'
                    , '시가': 'open', '고가': 'high', '저가': 'low', '거래량': 'volume'})
                df['date'] = df['date'].replace('.', '-')
                df = df.dropna()
                df[['close', 'diff', 'open', 'high', 'low', 'volume']] = df[['close',
                                                                             'diff', 'open', 'high', 'low',
                                                                             'volume']].astype(int)
                df = df[['date', 'open', 'high', 'low', 'close', 'diff', 'volume']]
        except Exception as e:
            print('Exception occured :', str(e))
            return None
        return df

    def replace_into_db(self, df, num, code, company):
        """네이버에서 읽어온 주식 시세를 DB에 REPLACE"""
        with self.conn.cursor() as curs:
            for r in df.itertuples():
                sql = f"REPLACE INTO daily_price VALUES ('{code}', " \
                      f"'{r.date}', {r.open}, {r.high}, {r.low}, {r.close}, " \
                      f"{r.diff}, {r.volume})"
                curs.execute(sql)
            self.conn.commit()
            print('[{}] #{:04d} {} ({}) : {} rows > REPLACE INTO daily_' \
                  'price [OK]'.format(datetime.now().strftime('%Y-%m-%d' \
                                                              ' %H:%M'), num + 1, company, code, len(df)))

    def update_daily_price(self, pages_to_fetch):
        """KRX 상장법인의 주식 시세를 네이버로부터 읽어서 DB에 업데이트"""
        for idx, code in enumerate(self.codes):
            df = self.read_naver(code, self.codes[code], pages_to_fetch)
            if df is None:
                continue
            self.replace_into_db(df, idx, code, self.codes[code])

    def execute_daily(self):
        """실행 즉시 및 매일 오후 다섯시에 daily_price 테이블 업데이트"""
        self.update_comp_info()

        try:
            with open('config.json', 'r') as in_file:
                config = json.load(in_file)
                pages_to_fetch = config['pages_to_fetch']
        except FileNotFoundError:
            with open('config.json', 'w') as out_file:
                pages_to_fetch = 100
                config = {'pages_to_fetch': 1}
                json.dump(config, out_file)
        self.update_daily_price(pages_to_fetch)

        tmnow = datetime.now()
        lastday = calendar.monthrange(tmnow.year, tmnow.month)[1]
        if tmnow.month == 12 and tmnow.day == lastday:
            tmnext = tmnow.replace(year=tmnow.year + 1, month=1, day=1,
                                   hour=17, minute=0, second=0)
        elif tmnow.day == lastday:
            tmnext = tmnow.replace(month=tmnow.month + 1, day=1, hour=17,
                                   minute=0, second=0)
        else:
            tmnext = tmnow.replace(day=tmnow.day + 1, hour=17, minute=0,
                                   second=0)
        tmdiff = tmnext - tmnow
        secs = tmdiff.seconds
        t = Timer(secs, self.execute_daily)
        print("Waiting for next update ({}) ... ".format(tmnext.strftime
                                                         ('%Y-%m-%d %H:%M')))
        t.start()


if __name__ == '__main__':
    dbu = DBUpdater()
    dbu.execute_daily()
# Out:
# [2021-10-02 18:59] #0001 REPLACE INTO company_info VALUES (004840, DRB동일, 2021-10-02)
# [2021-10-02 18:59] #0002 REPLACE INTO company_info VALUES (155660, DSR, 2021-10-02)
# [2021-10-02 18:59] #0003 REPLACE INTO company_info VALUES (078930, GS, 2021-10-02)
# [2021-10-02 18:59] #0004 REPLACE INTO company_info VALUES (001250, GS글로벌, 2021-10-02)
# [2021-10-02 18:59] #0005 REPLACE INTO company_info VALUES (294870, HDC현대산업개발, 2021-10-02)
# [2021-10-02 18:59] #0006 REPLACE INTO company_info VALUES (011200, HMM, 2021-10-02)
# [2021-10-02 18:59] #0007 REPLACE INTO company_info VALUES (092220, KEC, 2021-10-02)
# [2021-10-02 18:59] #0008 REPLACE INTO company_info VALUES (016380, KG동부제철, 2021-10-02)
# [2021-10-02 18:59] #0009 REPLACE INTO company_info VALUES (001390, KG케미칼, 2021-10-02)
# [2021-10-02 18:59] #0010 REPLACE INTO company_info VALUES (058860, KTis, 2021-10-02)
# [2021-10-02 18:59] #0011 REPLACE INTO company_info VALUES (011070, LG이노텍, 2021-10-02)
# [2021-10-02 18:59] #0012 REPLACE INTO company_info VALUES (066570, LG전자, 2021-10-02)
# [2021-10-02 18:59] #0013 REPLACE INTO company_info VALUES (037560, LG헬로비전, 2021-10-02)
# [2021-10-02 18:59] #0014 REPLACE INTO company_info VALUES (096770, SK이노베이션, 2021-10-02)
# [2021-10-02 18:59] #0015 REPLACE INTO company_info VALUES (011810, STX, 2021-10-02)
# [2021-10-02 18:59] #0016 REPLACE INTO company_info VALUES (024070, WISCOM, 2021-10-02)
# [2021-10-02 18:59] #0017 REPLACE INTO company_info VALUES (011420, 갤럭시아에스엠, 2021-10-02)
# [2021-10-02 18:59] #0018 REPLACE INTO company_info VALUES (002100, 경농, 2021-10-02)
# [2021-10-02 18:59] #0019 REPLACE INTO company_info VALUES (012320, 경동인베스트, 2021-10-02)
# [2021-10-02 18:59] #0020 REPLACE INTO company_info VALUES (007690, 국도화학, 2021-10-02)
# [2021-10-02 18:59] #0021 REPLACE INTO company_info VALUES (014530, 극동유화, 2021-10-02)
# [2021-10-02 18:59] #0022 REPLACE INTO company_info VALUES (000270, 기아, 2021-10-02)
# [2021-10-02 18:59] #0023 REPLACE INTO company_info VALUES (013700, 까뮤이앤씨, 2021-10-02)
# [2021-10-02 18:59] #0024 REPLACE INTO company_info VALUES (353200, 대덕전자, 2021-10-02)
# [2021-10-02 18:59] #0025 REPLACE INTO company_info VALUES (047040, 대우건설, 2021-10-02)
# [2021-10-02 18:59] #0026 REPLACE INTO company_info VALUES (003090, 대웅, 2021-10-02)
# [2021-10-02 18:59] #0027 REPLACE INTO company_info VALUES (024890, 대원화성, 2021-10-02)
# [2021-10-02 18:59] #0028 REPLACE INTO company_info VALUES (145720, 덴티움, 2021-10-02)
# [2021-10-02 18:59] #0029 REPLACE INTO company_info VALUES (042670, 두산인프라코어, 2021-10-02)
# [2021-10-02 18:59] #0030 REPLACE INTO company_info VALUES (026890, 디피씨, 2021-10-02)
# [2021-10-02 18:59] #0031 REPLACE INTO company_info VALUES (286940, 롯데정보통신, 2021-10-02)
# [2021-10-02 18:59] #0032 REPLACE INTO company_info VALUES (027740, 마니커, 2021-10-02)
# [2021-10-02 18:59] #0033 REPLACE INTO company_info VALUES (008560, 메리츠증권, 2021-10-02)
# [2021-10-02 18:59] #0034 REPLACE INTO company_info VALUES (017180, 명문제약, 2021-10-02)
# [2021-10-02 18:59] #0035 REPLACE INTO company_info VALUES (204210, 모두투어리츠, 2021-10-02)
# [2021-10-02 18:59] #0036 REPLACE INTO company_info VALUES (003850, 보령제약, 2021-10-02)
# [2021-10-02 18:59] #0037 REPLACE INTO company_info VALUES (001270, 부국증권, 2021-10-02)
# [2021-10-02 18:59] #0038 REPLACE INTO company_info VALUES (006400, 삼성SDI, 2021-10-02)
# [2021-10-02 18:59] #0039 REPLACE INTO company_info VALUES (028050, 삼성엔지니어링, 2021-10-02)
# [2021-10-02 18:59] #0040 REPLACE INTO company_info VALUES (068290, 삼성출판사, 2021-10-02)
# [2021-10-02 18:59] #0041 REPLACE INTO company_info VALUES (000810, 삼성화재해상보험, 2021-10-02)
# [2021-10-02 18:59] #0042 REPLACE INTO company_info VALUES (003720, 삼영화학공업, 2021-10-02)
# [2021-10-02 18:59] #0043 REPLACE INTO company_info VALUES (010960, 삼호개발, 2021-10-02)
# [2021-10-02 18:59] #0044 REPLACE INTO company_info VALUES (001290, 상상인증권, 2021-10-02)
# [2021-10-02 18:59] #0045 REPLACE INTO company_info VALUES (136490, 선진, 2021-10-02)
# [2021-10-02 18:59] #0046 REPLACE INTO company_info VALUES (002420, 세기상사, 2021-10-02)
# [2021-10-02 18:59] #0047 REPLACE INTO company_info VALUES (004490, 세방전지, 2021-10-02)
# [2021-10-02 18:59] #0048 REPLACE INTO company_info VALUES (003030, 세아제강지주, 2021-10-02)
# [2021-10-02 18:59] #0049 REPLACE INTO company_info VALUES (012600, 센트럴인사이트, 2021-10-02)
# [2021-10-02 18:59] #0050 REPLACE INTO company_info VALUES (293940, 신한알파리츠, 2021-10-02)
# [2021-10-02 18:59] #0051 REPLACE INTO company_info VALUES (055550, 신한지주, 2021-10-02)
# [2021-10-02 18:59] #0052 REPLACE INTO company_info VALUES (003620, 쌍용자동차, 2021-10-02)
# [2021-10-02 18:59] #0053 REPLACE INTO company_info VALUES (015540, 쎌마테라퓨틱스, 2021-10-02)
# [2021-10-02 18:59] #0054 REPLACE INTO company_info VALUES (137310, 에스디바이오센서, 2021-10-02)
# [2021-10-02 18:59] #0055 REPLACE INTO company_info VALUES (078520, 에이블씨엔씨, 2021-10-02)
# [2021-10-02 18:59] #0056 REPLACE INTO company_info VALUES (012280, 영화금속, 2021-10-02)
# [2021-10-02 18:59] #0057 REPLACE INTO company_info VALUES (007310, 오뚜기, 2021-10-02)
# [2021-10-02 18:59] #0058 REPLACE INTO company_info VALUES (002630, 오리엔트바이오, 2021-10-02)
# [2021-10-02 18:59] #0059 REPLACE INTO company_info VALUES (271560, 오리온, 2021-10-02)
# [2021-10-02 18:59] #0060 REPLACE INTO company_info VALUES (105840, 우진, 2021-10-02)
# [2021-10-02 18:59] #0061 REPLACE INTO company_info VALUES (008600, 윌비스, 2021-10-02)
# [2021-10-02 18:59] #0062 REPLACE INTO company_info VALUES (033270, 유나이티드, 2021-10-02)
# [2021-10-02 18:59] #0063 REPLACE INTO company_info VALUES (023800, 인지컨트롤스, 2021-10-02)
# [2021-10-02 18:59] #0064 REPLACE INTO company_info VALUES (129260, 인터지스, 2021-10-02)
# [2021-10-02 18:59] #0065 REPLACE INTO company_info VALUES (013360, 일성건설, 2021-10-02)
# [2021-10-02 18:59] #0066 REPLACE INTO company_info VALUES (081000, 일진다이아, 2021-10-02)
# [2021-10-02 18:59] #0067 REPLACE INTO company_info VALUES (033240, 자화전자, 2021-10-02)
# [2021-10-02 18:59] #0068 REPLACE INTO company_info VALUES (271980, 제일약품, 2021-10-02)
# [2021-10-02 18:59] #0069 REPLACE INTO company_info VALUES (002620, 제일파마홀딩스, 2021-10-02)
# [2021-10-02 18:59] #0070 REPLACE INTO company_info VALUES (001550, 조비, 2021-10-02)
# [2021-10-02 18:59] #0071 REPLACE INTO company_info VALUES (002600, 조흥, 2021-10-02)
# [2021-10-02 18:59] #0072 REPLACE INTO company_info VALUES (001630, 종근당홀딩스, 2021-10-02)
# [2021-10-02 18:59] #0073 REPLACE INTO company_info VALUES (071320, 지역난방공사, 2021-10-02)
# [2021-10-02 18:59] #0074 REPLACE INTO company_info VALUES (120110, 코오롱인더, 2021-10-02)
# [2021-10-02 18:59] #0075 REPLACE INTO company_info VALUES (020120, 키다리스튜디오, 2021-10-02)
# [2021-10-02 18:59] #0076 REPLACE INTO company_info VALUES (015890, 태경산업, 2021-10-02)
# [2021-10-02 18:59] #0077 REPLACE INTO company_info VALUES (004100, 태양금속공업, 2021-10-02)
# [2021-10-02 18:59] #0078 REPLACE INTO company_info VALUES (005490, 포스코, 2021-10-02)
# [2021-10-02 18:59] #0079 REPLACE INTO company_info VALUES (058430, 포스코강판, 2021-10-02)
# [2021-10-02 18:59] #0080 REPLACE INTO company_info VALUES (352820, 하이브, 2021-10-02)
# [2021-10-02 18:59] #0081 REPLACE INTO company_info VALUES (005430, 한국공항, 2021-10-02)
# [2021-10-02 18:59] #0082 REPLACE INTO company_info VALUES (168490, 한국패러랠, 2021-10-02)
# [2021-10-02 18:59] #0083 REPLACE INTO company_info VALUES (009180, 한솔로지스틱스, 2021-10-02)
# [2021-10-02 18:59] #0084 REPLACE INTO company_info VALUES (002220, 한일철강, 2021-10-02)
# [2021-10-02 18:59] #0085 REPLACE INTO company_info VALUES (009460, 한창제지, 2021-10-02)
# [2021-10-02 18:59] #0086 REPLACE INTO company_info VALUES (088350, 한화생명, 2021-10-02)
# [2021-10-02 18:59] #0087 REPLACE INTO company_info VALUES (000720, 현대건설, 2021-10-02)
# [2021-10-02 18:59] #0088 REPLACE INTO company_info VALUES (267270, 현대건설기계, 2021-10-02)
# [2021-10-02 18:59] #0089 REPLACE INTO company_info VALUES (004560, 현대비앤지스틸, 2021-10-02)
# [2021-10-02 18:59] #0090 REPLACE INTO company_info VALUES (017800, 현대엘리베이터, 2021-10-02)
# [2021-10-02 18:59] #0091 REPLACE INTO company_info VALUES (001500, 현대차증권, 2021-10-02)
# [2021-10-02 18:59] #0092 REPLACE INTO company_info VALUES (111110, 호전실업, 2021-10-02)
# [2021-10-02 18:59] #0093 REPLACE INTO company_info VALUES (003280, 흥아해운, 2021-10-02)
# [2021-10-02 18:59] #0094 REPLACE INTO company_info VALUES (060310, 3S, 2021-10-02)
# [2021-10-02 18:59] #0095 REPLACE INTO company_info VALUES (013720, CBI, 2021-10-02)
# [2021-10-02 18:59] #0096 REPLACE INTO company_info VALUES (245620, EDGC, 2021-10-02)
# [2021-10-02 18:59] #0097 REPLACE INTO company_info VALUES (050120, ES큐브, 2021-10-02)
# [2021-10-02 18:59] #0098 REPLACE INTO company_info VALUES (195940, HK이노엔, 2021-10-02)
# [2021-10-02 18:59] #0099 REPLACE INTO company_info VALUES (067290, JW신약, 2021-10-02)
# [2021-10-02 18:59] #0100 REPLACE INTO company_info VALUES (024120, KB오토시스, 2021-10-02)
# [2021-10-02 18:59] #0101 REPLACE INTO company_info VALUES (060720, KH바텍, 2021-10-02)
# [2021-10-02 18:59] #0102 REPLACE INTO company_info VALUES (024940, PN풍년, 2021-10-02)
# [2021-10-02 18:59] #0103 REPLACE INTO company_info VALUES (036120, SCI평가정보, 2021-10-02)
# [2021-10-02 18:59] #0104 REPLACE INTO company_info VALUES (255220, SG, 2021-10-02)
# [2021-10-02 18:59] #0105 REPLACE INTO company_info VALUES (032540, TJ미디어, 2021-10-02)
# [2021-10-02 18:59] #0106 REPLACE INTO company_info VALUES (038340, UCI, 2021-10-02)
# [2021-10-02 18:59] #0107 REPLACE INTO company_info VALUES (217730, 강스템바이오텍, 2021-10-02)
# [2021-10-02 18:59] #0108 REPLACE INTO company_info VALUES (053950, 경남제약, 2021-10-02)
# [2021-10-02 18:59] #0109 REPLACE INTO company_info VALUES (024910, 경창산업, 2021-10-02)
# [2021-10-02 18:59] #0110 REPLACE INTO company_info VALUES (331520, 교보9호스팩, 2021-10-02)
# [2021-10-02 18:59] #0111 REPLACE INTO company_info VALUES (043650, 국순당, 2021-10-02)
# [2021-10-02 18:59] #0112 REPLACE INTO company_info VALUES (078130, 국일제지, 2021-10-02)
# [2021-10-02 18:59] #0113 REPLACE INTO company_info VALUES (204020, 그리티, 2021-10-02)
# [2021-10-02 18:59] #0114 REPLACE INTO company_info VALUES (019660, 글로본, 2021-10-02)
# [2021-10-02 18:59] #0115 REPLACE INTO company_info VALUES (308100, 까스텔바작, 2021-10-02)
# [2021-10-02 18:59] #0116 REPLACE INTO company_info VALUES (286750, 나노브릭, 2021-10-02)
# [2021-10-02 18:59] #0117 REPLACE INTO company_info VALUES (151910, 나노스, 2021-10-02)
# [2021-10-02 18:59] #0118 REPLACE INTO company_info VALUES (094860, 네오리진, 2021-10-02)
# [2021-10-02 18:59] #0119 REPLACE INTO company_info VALUES (095660, 네오위즈, 2021-10-02)
# [2021-10-02 18:59] #0120 REPLACE INTO company_info VALUES (085910, 네오티스, 2021-10-02)
# [2021-10-02 18:59] #0121 REPLACE INTO company_info VALUES (007390, 네이처셀, 2021-10-02)
# [2021-10-02 18:59] #0122 REPLACE INTO company_info VALUES (031390, 녹십자셀, 2021-10-02)
# [2021-10-02 18:59] #0123 REPLACE INTO company_info VALUES (054050, 농우바이오, 2021-10-02)
# [2021-10-02 18:59] #0124 REPLACE INTO company_info VALUES (012340, 뉴인텍, 2021-10-02)
# [2021-10-02 18:59] #0125 REPLACE INTO company_info VALUES (340360, 다보링크, 2021-10-02)
# [2021-10-02 18:59] #0126 REPLACE INTO company_info VALUES (078140, 대봉엘에스, 2021-10-02)
# [2021-10-02 18:59] #0127 REPLACE INTO company_info VALUES (290380, 대유, 2021-10-02)
# [2021-10-02 18:59] #0128 REPLACE INTO company_info VALUES (290120, 대유에이피, 2021-10-02)
# [2021-10-02 18:59] #0129 REPLACE INTO company_info VALUES (003310, 대주산업, 2021-10-02)
# [2021-10-02 18:59] #0130 REPLACE INTO company_info VALUES (060900, 대한그린파워, 2021-10-02)
# [2021-10-02 18:59] #0131 REPLACE INTO company_info VALUES (023910, 대한약품, 2021-10-02)
# [2021-10-02 18:59] #0132 REPLACE INTO company_info VALUES (006620, 동구바이오제약, 2021-10-02)
# [2021-10-02 18:59] #0133 REPLACE INTO company_info VALUES (196490, 디에이테크놀로지, 2021-10-02)
# [2021-10-02 18:59] #0134 REPLACE INTO company_info VALUES (066900, 디에이피, 2021-10-02)
# [2021-10-02 18:59] #0135 REPLACE INTO company_info VALUES (127120, 디엔에이링크, 2021-10-02)
# [2021-10-02 18:59] #0136 REPLACE INTO company_info VALUES (033130, 디지틀조선, 2021-10-02)
# [2021-10-02 18:59] #0137 REPLACE INTO company_info VALUES (060240, 룽투코리아, 2021-10-02)
# [2021-10-02 18:59] #0138 REPLACE INTO company_info VALUES (219420, 링크제니시스, 2021-10-02)
# [2021-10-02 18:59] #0139 REPLACE INTO company_info VALUES (250060, 모비스, 2021-10-02)
# [2021-10-02 18:59] #0140 REPLACE INTO company_info VALUES (118990, 모트렉스, 2021-10-02)
# [2021-10-02 18:59] #0141 REPLACE INTO company_info VALUES (328380, 미래에셋대우스팩3호, 2021-10-02)
# [2021-10-02 18:59] #0142 REPLACE INTO company_info VALUES (214610, 미코바이오메드, 2021-10-02)
# [2021-10-02 18:59] #0143 REPLACE INTO company_info VALUES (019010, 베뉴지, 2021-10-02)
# [2021-10-02 18:59] #0144 REPLACE INTO company_info VALUES (337930, 브랜드엑스코퍼레이션, 2021-10-02)
# [2021-10-02 18:59] #0145 REPLACE INTO company_info VALUES (023600, 삼보판지, 2021-10-02)
# [2021-10-02 18:59] #0146 REPLACE INTO company_info VALUES (377630, 삼성스팩4호, 2021-10-02)
# [2021-10-02 18:59] #0147 REPLACE INTO company_info VALUES (009300, 삼아제약, 2021-10-02)
# [2021-10-02 18:59] #0148 REPLACE INTO company_info VALUES (032280, 삼일, 2021-10-02)
# [2021-10-02 18:59] #0149 REPLACE INTO company_info VALUES (252990, 샘씨엔에스, 2021-10-02)
# [2021-10-02 18:59] #0150 REPLACE INTO company_info VALUES (100660, 서암기계공업, 2021-10-02)
# [2021-10-02 18:59] #0151 REPLACE INTO company_info VALUES (086710, 선진뷰티사이언스, 2021-10-02)
# [2021-10-02 18:59] #0152 REPLACE INTO company_info VALUES (080470, 성창오토텍, 2021-10-02)
# [2021-10-02 18:59] #0153 REPLACE INTO company_info VALUES (208370, 셀바스헬스케어, 2021-10-02)
# [2021-10-02 18:59] #0154 REPLACE INTO company_info VALUES (115570, 스타플렉스, 2021-10-02)
# [2021-10-02 18:59] #0155 REPLACE INTO company_info VALUES (013810, 스페코, 2021-10-02)
# [2021-10-02 18:59] #0156 REPLACE INTO company_info VALUES (139050, 시티랩스, 2021-10-02)
# [2021-10-02 18:59] #0157 REPLACE INTO company_info VALUES (344050, 신영스팩6호, 2021-10-02)
# [2021-10-02 18:59] #0158 REPLACE INTO company_info VALUES (010280, 쌍용정보통신, 2021-10-02)
# [2021-10-02 18:59] #0159 REPLACE INTO company_info VALUES (208640, 썸에이지, 2021-10-02)
# [2021-10-02 18:59] #0160 REPLACE INTO company_info VALUES (136510, 쎄미시스코, 2021-10-02)
# [2021-10-02 18:59] #0161 REPLACE INTO company_info VALUES (900120, 씨케이에이치, 2021-10-02)
# [2021-10-02 18:59] #0162 REPLACE INTO company_info VALUES (339950, 아이비김영, 2021-10-02)
# [2021-10-02 18:59] #0163 REPLACE INTO company_info VALUES (099190, 아이센스, 2021-10-02)
# [2021-10-02 18:59] #0164 REPLACE INTO company_info VALUES (040910, 아이씨디, 2021-10-02)
# [2021-10-02 18:59] #0165 REPLACE INTO company_info VALUES (068940, 아이씨케이, 2021-10-02)
# [2021-10-02 18:59] #0166 REPLACE INTO company_info VALUES (069920, 아이에스이커머스, 2021-10-02)
# [2021-10-02 18:59] #0167 REPLACE INTO company_info VALUES (114810, 아이원스, 2021-10-02)
# [2021-10-02 18:59] #0168 REPLACE INTO company_info VALUES (031310, 아이즈비전, 2021-10-02)
# [2021-10-02 18:59] #0169 REPLACE INTO company_info VALUES (059100, 아이컴포넌트, 2021-10-02)
# [2021-10-02 18:59] #0170 REPLACE INTO company_info VALUES (175250, 아이큐어, 2021-10-02)
# [2021-10-02 18:59] #0171 REPLACE INTO company_info VALUES (124500, 아이티센, 2021-10-02)
# [2021-10-02 18:59] #0172 REPLACE INTO company_info VALUES (096610, 알에프세미, 2021-10-02)
# [2021-10-02 18:59] #0173 REPLACE INTO company_info VALUES (061040, 알에프텍, 2021-10-02)
# [2021-10-02 18:59] #0174 REPLACE INTO company_info VALUES (117670, 알파홀딩스, 2021-10-02)
# [2021-10-02 18:59] #0175 REPLACE INTO company_info VALUES (310200, 애니플러스, 2021-10-02)
# [2021-10-02 18:59] #0176 REPLACE INTO company_info VALUES (238090, 앤디포스, 2021-10-02)
# [2021-10-02 18:59] #0177 REPLACE INTO company_info VALUES (174900, 앱클론, 2021-10-02)
# [2021-10-02 18:59] #0178 REPLACE INTO company_info VALUES (102120, 어보브반도체, 2021-10-02)
# [2021-10-02 18:59] #0179 REPLACE INTO company_info VALUES (065420, 에스아이리소스, 2021-10-02)
# [2021-10-02 18:59] #0180 REPLACE INTO company_info VALUES (103230, 에스앤더블류, 2021-10-02)
# [2021-10-02 18:59] #0181 REPLACE INTO company_info VALUES (095910, 에스에너지, 2021-10-02)
# [2021-10-02 18:59] #0182 REPLACE INTO company_info VALUES (056190, 에스에프에이, 2021-10-02)
# [2021-10-02 18:59] #0183 REPLACE INTO company_info VALUES (043340, 에쎈테크, 2021-10-02)
# [2021-10-02 18:59] #0184 REPLACE INTO company_info VALUES (200710, 에이디테크놀로지, 2021-10-02)
# [2021-10-02 18:59] #0185 REPLACE INTO company_info VALUES (241840, 에이스토리, 2021-10-02)
# [2021-10-02 18:59] #0186 REPLACE INTO company_info VALUES (021080, 에이티넘인베스트, 2021-10-02)
# [2021-10-02 18:59] #0187 REPLACE INTO company_info VALUES (950130, 엑세스바이오, 2021-10-02)
# [2021-10-02 18:59] #0188 REPLACE INTO company_info VALUES (092870, 엑시콘, 2021-10-02)
# [2021-10-02 18:59] #0189 REPLACE INTO company_info VALUES (101400, 엔시트론, 2021-10-02)
# [2021-10-02 18:59] #0190 REPLACE INTO company_info VALUES (365590, 엔에이치스팩18호, 2021-10-02)
# [2021-10-02 18:59] #0191 REPLACE INTO company_info VALUES (182400, 엔케이맥스, 2021-10-02)
# [2021-10-02 18:59] #0192 REPLACE INTO company_info VALUES (227950, 엔투텍, 2021-10-02)
# [2021-10-02 18:59] #0193 REPLACE INTO company_info VALUES (138690, 엘아이에스, 2021-10-02)
# [2021-10-02 18:59] #0194 REPLACE INTO company_info VALUES (058630, 엠게임, 2021-10-02)
# [2021-10-02 18:59] #0195 REPLACE INTO company_info VALUES (019590, 엠벤처투자, 2021-10-02)
# [2021-10-02 18:59] #0196 REPLACE INTO company_info VALUES (032790, 엠젠플러스, 2021-10-02)
# [2021-10-02 18:59] #0197 REPLACE INTO company_info VALUES (265560, 영화테크, 2021-10-02)
# [2021-10-02 18:59] #0198 REPLACE INTO company_info VALUES (122640, 예스티, 2021-10-02)
# [2021-10-02 18:59] #0199 REPLACE INTO company_info VALUES (045060, 오공, 2021-10-02)
# [2021-10-02 18:59] #0200 REPLACE INTO company_info VALUES (080520, 오디텍, 2021-10-02)
# [2021-10-02 18:59] #0201 REPLACE INTO company_info VALUES (048260, 오스템임플란트, 2021-10-02)
# [2021-10-02 18:59] #0202 REPLACE INTO company_info VALUES (049480, 오픈베이스, 2021-10-02)
# [2021-10-02 18:59] #0203 REPLACE INTO company_info VALUES (109080, 옵티시스, 2021-10-02)
# [2021-10-02 18:59] #0204 REPLACE INTO company_info VALUES (065950, 웰크론, 2021-10-02)
# [2021-10-02 18:59] #0205 REPLACE INTO company_info VALUES (036090, 위지트, 2021-10-02)
# [2021-10-02 18:59] #0206 REPLACE INTO company_info VALUES (203450, 유니온커뮤니티, 2021-10-02)
# [2021-10-02 18:59] #0207 REPLACE INTO company_info VALUES (241690, 유니테크노, 2021-10-02)
# [2021-10-02 18:59] #0208 REPLACE INTO company_info VALUES (078070, 유비쿼스홀딩스, 2021-10-02)
# [2021-10-02 18:59] #0209 REPLACE INTO company_info VALUES (054930, 유신, 2021-10-02)
# [2021-10-02 18:59] #0210 REPLACE INTO company_info VALUES (049520, 유아이엘, 2021-10-02)
# [2021-10-02 18:59] #0211 REPLACE INTO company_info VALUES (336060, 유안타제5호스팩, 2021-10-02)
# [2021-10-02 18:59] #0212 REPLACE INTO company_info VALUES (367460, 유안타제7호스팩, 2021-10-02)
# [2021-10-02 18:59] #0213 REPLACE INTO company_info VALUES (321260, 유진스팩4호, 2021-10-02)
# [2021-10-02 18:59] #0214 REPLACE INTO company_info VALUES (178780, 유테크, 2021-10-02)
# [2021-10-02 18:59] #0215 REPLACE INTO company_info VALUES (179900, 유티아이, 2021-10-02)
# [2021-10-02 18:59] #0216 REPLACE INTO company_info VALUES (349720, 이베스트스팩5호, 2021-10-02)
# [2021-10-02 18:59] #0217 REPLACE INTO company_info VALUES (323210, 이베스트이안스팩1호, 2021-10-02)
# [2021-10-02 18:59] #0218 REPLACE INTO company_info VALUES (047560, 이스트소프트, 2021-10-02)
# [2021-10-02 18:59] #0219 REPLACE INTO company_info VALUES (900110, 이스트아시아홀딩스, 2021-10-02)
# [2021-10-02 18:59] #0220 REPLACE INTO company_info VALUES (123570, 이엠넷, 2021-10-02)
# [2021-10-02 18:59] #0221 REPLACE INTO company_info VALUES (353810, 이지바이오, 2021-10-02)
# [2021-10-02 18:59] #0222 REPLACE INTO company_info VALUES (064290, 인텍플러스, 2021-10-02)
# [2021-10-02 18:59] #0223 REPLACE INTO company_info VALUES (115310, 인포바인, 2021-10-02)
# [2021-10-02 18:59] #0224 REPLACE INTO company_info VALUES (333430, 일승, 2021-10-02)
# [2021-10-02 18:59] #0225 REPLACE INTO company_info VALUES (049550, 잉크테크, 2021-10-02)
# [2021-10-02 18:59] #0226 REPLACE INTO company_info VALUES (254120, 자비스, 2021-10-02)
# [2021-10-02 18:59] #0227 REPLACE INTO company_info VALUES (234920, 자이글, 2021-10-02)
# [2021-10-02 18:59] #0228 REPLACE INTO company_info VALUES (040420, 정상제이엘에스, 2021-10-02)
# [2021-10-02 18:59] #0229 REPLACE INTO company_info VALUES (079370, 제우스, 2021-10-02)
# [2021-10-02 18:59] #0230 REPLACE INTO company_info VALUES (137950, 제이씨케미칼, 2021-10-02)
# [2021-10-02 18:59] #0231 REPLACE INTO company_info VALUES (033320, 제이씨현시스템, 2021-10-02)
# [2021-10-02 18:59] #0232 REPLACE INTO company_info VALUES (322510, 제이엘케이, 2021-10-02)
# [2021-10-02 18:59] #0233 REPLACE INTO company_info VALUES (094970, 제이엠티, 2021-10-02)
# [2021-10-02 18:59] #0234 REPLACE INTO company_info VALUES (080220, 제주반도체, 2021-10-02)
# [2021-10-02 18:59] #0235 REPLACE INTO company_info VALUES (034940, 조아제약, 2021-10-02)
# [2021-10-02 18:59] #0236 REPLACE INTO company_info VALUES (036930, 주성엔지니어링, 2021-10-02)
# [2021-10-02 18:59] #0237 REPLACE INTO company_info VALUES (263860, 지니언스, 2021-10-02)
# [2021-10-02 18:59] #0238 REPLACE INTO company_info VALUES (119850, 지엔씨에너지, 2021-10-02)
# [2021-10-02 18:59] #0239 REPLACE INTO company_info VALUES (052300, 초록뱀컴퍼니, 2021-10-02)
# [2021-10-02 18:59] #0240 REPLACE INTO company_info VALUES (071850, 캐스텍코리아, 2021-10-02)
# [2021-10-02 18:59] #0241 REPLACE INTO company_info VALUES (078340, 컴투스, 2021-10-02)
# [2021-10-02 18:59] #0242 REPLACE INTO company_info VALUES (342550, 케이비제20호스팩, 2021-10-02)
# [2021-10-02 18:59] #0243 REPLACE INTO company_info VALUES (347140, 케이프이에스제4호, 2021-10-02)
# [2021-10-02 18:59] #0244 REPLACE INTO company_info VALUES (054410, 케이피티유, 2021-10-02)
# [2021-10-02 18:59] #0245 REPLACE INTO company_info VALUES (274090, 켄코아에어로스페이스, 2021-10-02)
# [2021-10-02 18:59] #0246 REPLACE INTO company_info VALUES (082660, 코스나인, 2021-10-02)
# [2021-10-02 18:59] #0247 REPLACE INTO company_info VALUES (069110, 코스온, 2021-10-02)
# [2021-10-02 18:59] #0248 REPLACE INTO company_info VALUES (102940, 코오롱생명과학, 2021-10-02)
# [2021-10-02 18:59] #0249 REPLACE INTO company_info VALUES (126600, 코프라, 2021-10-02)
# [2021-10-02 18:59] #0250 REPLACE INTO company_info VALUES (139670, 키네마스터, 2021-10-02)
# [2021-10-02 18:59] #0251 REPLACE INTO company_info VALUES (131970, 테스나, 2021-10-02)
# [2021-10-02 18:59] #0252 REPLACE INTO company_info VALUES (045340, 토탈소프트, 2021-10-02)
# [2021-10-02 18:59] #0253 REPLACE INTO company_info VALUES (105550, 트루윈, 2021-10-02)
# [2021-10-02 18:59] #0254 REPLACE INTO company_info VALUES (026150, 특수건설, 2021-10-02)
# [2021-10-02 18:59] #0255 REPLACE INTO company_info VALUES (246710, 티앤알바이오팹, 2021-10-02)
# [2021-10-02 18:59] #0256 REPLACE INTO company_info VALUES (033540, 파라텍, 2021-10-02)
# [2021-10-02 18:59] #0257 REPLACE INTO company_info VALUES (065690, 파커스, 2021-10-02)
# [2021-10-02 18:59] #0258 REPLACE INTO company_info VALUES (225590, 패션플랫폼, 2021-10-02)
# [2021-10-02 18:59] #0259 REPLACE INTO company_info VALUES (256630, 포인트엔지니어링, 2021-10-02)
# [2021-10-02 18:59] #0260 REPLACE INTO company_info VALUES (005670, 푸드웰, 2021-10-02)
# [2021-10-02 18:59] #0261 REPLACE INTO company_info VALUES (203690, 프로스테믹스, 2021-10-02)
# [2021-10-02 18:59] #0262 REPLACE INTO company_info VALUES (377220, 프롬바이오, 2021-10-02)
# [2021-10-02 18:59] #0263 REPLACE INTO company_info VALUES (032580, 피델릭스, 2021-10-02)
# [2021-10-02 18:59] #0264 REPLACE INTO company_info VALUES (024850, 피에스엠씨, 2021-10-02)
# [2021-10-02 18:59] #0265 REPLACE INTO company_info VALUES (319660, 피에스케이, 2021-10-02)
# [2021-10-02 18:59] #0266 REPLACE INTO company_info VALUES (031980, 피에스케이홀딩스, 2021-10-02)
# [2021-10-02 18:59] #0267 REPLACE INTO company_info VALUES (006140, 피제이전자, 2021-10-02)
# [2021-10-02 18:59] #0268 REPLACE INTO company_info VALUES (161580, 필옵틱스, 2021-10-02)
# [2021-10-02 18:59] #0269 REPLACE INTO company_info VALUES (341160, 하나금융15호스팩, 2021-10-02)
# [2021-10-02 18:59] #0270 REPLACE INTO company_info VALUES (299030, 하나기술, 2021-10-02)
# [2021-10-02 18:59] #0271 REPLACE INTO company_info VALUES (221840, 하이즈항공, 2021-10-02)
# [2021-10-02 18:59] #0272 REPLACE INTO company_info VALUES (039340, 한국경제TV, 2021-10-02)
# [2021-10-02 18:59] #0273 REPLACE INTO company_info VALUES (222980, 한국맥널티, 2021-10-02)
# [2021-10-02 18:59] #0274 REPLACE INTO company_info VALUES (053590, 한국테크놀로지, 2021-10-02)
# [2021-10-02 18:59] #0275 REPLACE INTO company_info VALUES (070590, 한솔인티큐브, 2021-10-02)
# [2021-10-02 18:59] #0276 REPLACE INTO company_info VALUES (078350, 한양디지텍, 2021-10-02)
# [2021-10-02 18:59] #0277 REPLACE INTO company_info VALUES (340440, 한화플러스제1호스팩, 2021-10-02)
# [2021-10-02 18:59] #0278 REPLACE INTO company_info VALUES (386580, 한화플러스제2호스팩, 2021-10-02)
# [2021-10-02 18:59] #0279 REPLACE INTO company_info VALUES (076610, 해성옵틱스, 2021-10-02)
# [2021-10-02 18:59] #0280 REPLACE INTO company_info VALUES (319400, 현대무벡스, 2021-10-02)
# [2021-10-02 18:59] #0281 REPLACE INTO company_info VALUES (048410, 현대바이오, 2021-10-02)
# [2021-10-02 18:59] #0282 REPLACE INTO company_info VALUES (052260, 현대바이오랜드, 2021-10-02)
# [2021-10-02 18:59] #0283 REPLACE INTO company_info VALUES (039610, 화성밸브, 2021-10-02)
# [2021-10-02 18:59] #0284 REPLACE INTO company_info VALUES (090710, 휴림로봇, 2021-10-02)
# [2021-10-02 18:59] #0285 REPLACE INTO company_info VALUES (037440, 희림, 2021-10-02)
# [2021-10-02 18:59] #0286 REPLACE INTO company_info VALUES (076340, 관악산업, 2021-10-02)
# [2021-10-02 18:59] #0287 REPLACE INTO company_info VALUES (244880, 나눔테크, 2021-10-02)
# [2021-10-02 18:59] #0288 REPLACE INTO company_info VALUES (323350, 다원넥스뷰, 2021-10-02)
# [2021-10-02 18:59] #0289 REPLACE INTO company_info VALUES (086080, 다이노나, 2021-10-02)
# [2021-10-02 18:59] #0290 REPLACE INTO company_info VALUES (271850, 다이오진, 2021-10-02)
# [2021-10-02 18:59] #0291 REPLACE INTO company_info VALUES (267060, 명진홀딩스, 2021-10-02)
# [2021-10-02 18:59] #0292 REPLACE INTO company_info VALUES (067370, 선바이오, 2021-10-02)
# [2021-10-02 18:59] #0293 REPLACE INTO company_info VALUES (103660, 씨앗, 2021-10-02)
# [2021-10-02 18:59] #0294 REPLACE INTO company_info VALUES (270210, 에스알바이오텍, 2021-10-02)
# [2021-10-02 18:59] #0295 REPLACE INTO company_info VALUES (322190, 에이스캠퍼, 2021-10-02)
# [2021-10-02 18:59] #0296 REPLACE INTO company_info VALUES (276240, 엘리비젼, 2021-10-02)
# [2021-10-02 18:59] #0297 REPLACE INTO company_info VALUES (221800, 유투바이오, 2021-10-02)
# [2021-10-02 18:59] #0298 REPLACE INTO company_info VALUES (336040, 이도바이오, 2021-10-02)
# [2021-10-02 18:59] #0299 REPLACE INTO company_info VALUES (250030, 진코스텍, 2021-10-02)
# [2021-10-02 18:59] #0300 REPLACE INTO company_info VALUES (136660, 큐엠씨, 2021-10-02)
# [2021-10-02 18:59] #0301 REPLACE INTO company_info VALUES (309900, 티티씨디펜스, 2021-10-02)
# [2021-10-02 18:59] #0302 REPLACE INTO company_info VALUES (217880, 틸론, 2021-10-02)
# [2021-10-02 18:59] #0303 REPLACE INTO company_info VALUES (000120, CJ대한통운, 2021-10-02)
# [2021-10-02 18:59] #0304 REPLACE INTO company_info VALUES (097950, CJ제일제당, 2021-10-02)
# [2021-10-02 18:59] #0305 REPLACE INTO company_info VALUES (007070, GS리테일, 2021-10-02)
# [2021-10-02 18:59] #0306 REPLACE INTO company_info VALUES (105560, KB금융, 2021-10-02)
# [2021-10-02 18:59] #0307 REPLACE INTO company_info VALUES (025000, KPX케미칼, 2021-10-02)
# [2021-10-02 18:59] #0308 REPLACE INTO company_info VALUES (000040, KR모터스, 2021-10-02)
# [2021-10-02 18:59] #0309 REPLACE INTO company_info VALUES (058850, KTcs, 2021-10-02)
# [2021-10-02 18:59] #0310 REPLACE INTO company_info VALUES (229640, LS전선아시아, 2021-10-02)
# [2021-10-02 18:59] #0311 REPLACE INTO company_info VALUES (068400, SK렌터카, 2021-10-02)
# [2021-10-02 18:59] #0312 REPLACE INTO company_info VALUES (005610, SPC삼립, 2021-10-02)
# [2021-10-02 18:59] #0313 REPLACE INTO company_info VALUES (035250, 강원랜드, 2021-10-02)
# [2021-10-02 18:59] #0314 REPLACE INTO company_info VALUES (030610, 교보증권, 2021-10-02)
# [2021-10-02 18:59] #0315 REPLACE INTO company_info VALUES (014280, 금강공업, 2021-10-02)
# [2021-10-02 18:59] #0316 REPLACE INTO company_info VALUES (002990, 금호건설, 2021-10-02)
# [2021-10-02 18:59] #0317 REPLACE INTO company_info VALUES (001210, 금호전기, 2021-10-02)
# [2021-10-02 18:59] #0318 REPLACE INTO company_info VALUES (024110, 기업은행, 2021-10-02)
# [2021-10-02 18:59] #0319 REPLACE INTO company_info VALUES (004270, 남성, 2021-10-02)
# [2021-10-02 18:59] #0320 REPLACE INTO company_info VALUES (251270, 넷마블, 2021-10-02)
# [2021-10-02 18:59] #0321 REPLACE INTO company_info VALUES (006370, 대구백화점, 2021-10-02)
# [2021-10-02 18:59] #0322 REPLACE INTO company_info VALUES (014160, 대영포장, 2021-10-02)
# [2021-10-02 18:59] #0323 REPLACE INTO company_info VALUES (003220, 대원제약, 2021-10-02)
# [2021-10-02 18:59] #0324 REPLACE INTO company_info VALUES (001070, 대한방직, 2021-10-02)
# [2021-10-02 18:59] #0325 REPLACE INTO company_info VALUES (001790, 대한제당, 2021-10-02)
# [2021-10-02 18:59] #0326 REPLACE INTO company_info VALUES (005880, 대한해운, 2021-10-02)
# [2021-10-02 18:59] #0327 REPLACE INTO company_info VALUES (024900, 덕양산업, 2021-10-02)
# [2021-10-02 18:59] #0328 REPLACE INTO company_info VALUES (049770, 동원F&B, 2021-10-02)
# [2021-10-02 18:59] #0329 REPLACE INTO company_info VALUES (018500, 동원금속, 2021-10-02)
# [2021-10-02 18:59] #0330 REPLACE INTO company_info VALUES (024090, 디씨엠, 2021-10-02)
# [2021-10-02 18:59] #0331 REPLACE INTO company_info VALUES (377190, 디앤디플랫폼리츠, 2021-10-02)
# [2021-10-02 18:59] #0332 REPLACE INTO company_info VALUES (007340, 디티알오토모티브, 2021-10-02)
# [2021-10-02 18:59] #0333 REPLACE INTO company_info VALUES (115390, 락앤락, 2021-10-02)
# [2021-10-02 18:59] #0334 REPLACE INTO company_info VALUES (280360, 롯데제과, 2021-10-02)
# [2021-10-02 18:59] #0335 REPLACE INTO company_info VALUES (071840, 롯데하이마트, 2021-10-02)
# [2021-10-02 18:59] #0336 REPLACE INTO company_info VALUES (035150, 백산, 2021-10-02)
# [2021-10-02 18:59] #0337 REPLACE INTO company_info VALUES (002760, 보락, 2021-10-02)
# [2021-10-02 18:59] #0338 REPLACE INTO company_info VALUES (005180, 빙그레, 2021-10-02)
# [2021-10-02 18:59] #0339 REPLACE INTO company_info VALUES (003960, 사조대림, 2021-10-02)
# [2021-10-02 18:59] #0340 REPLACE INTO company_info VALUES (008040, 사조동아원, 2021-10-02)
# [2021-10-02 18:59] #0341 REPLACE INTO company_info VALUES (005500, 삼진제약, 2021-10-02)
# [2021-10-02 18:59] #0342 REPLACE INTO company_info VALUES (021050, 서원, 2021-10-02)
# [2021-10-02 18:59] #0343 REPLACE INTO company_info VALUES (004360, 세방, 2021-10-02)
# [2021-10-02 18:59] #0344 REPLACE INTO company_info VALUES (058650, 세아홀딩스, 2021-10-02)
# [2021-10-02 18:59] #0345 REPLACE INTO company_info VALUES (013000, 세우글로벌, 2021-10-02)
# [2021-10-02 18:59] #0346 REPLACE INTO company_info VALUES (067830, 세이브존I&C, 2021-10-02)
# [2021-10-02 18:59] #0347 REPLACE INTO company_info VALUES (336370, 솔루스첨단소재, 2021-10-02)
# [2021-10-02 18:59] #0348 REPLACE INTO company_info VALUES (006880, 신송홀딩스, 2021-10-02)
# [2021-10-02 18:59] #0349 REPLACE INTO company_info VALUES (002700, 신일전자, 2021-10-02)
# [2021-10-02 18:59] #0350 REPLACE INTO company_info VALUES (019170, 신풍제약, 2021-10-02)
# [2021-10-02 18:59] #0351 REPLACE INTO company_info VALUES (122900, 아이마켓코리아, 2021-10-02)
# [2021-10-02 18:59] #0352 REPLACE INTO company_info VALUES (003560, 아이에이치큐, 2021-10-02)
# [2021-10-02 18:59] #0353 REPLACE INTO company_info VALUES (036570, 엔씨소프트, 2021-10-02)
# [2021-10-02 18:59] #0354 REPLACE INTO company_info VALUES (009810, 엔케이물산, 2021-10-02)
# [2021-10-02 18:59] #0355 REPLACE INTO company_info VALUES (014440, 영보화학, 2021-10-02)
# [2021-10-02 18:59] #0356 REPLACE INTO company_info VALUES (003520, 영진약품, 2021-10-02)
# [2021-10-02 18:59] #0357 REPLACE INTO company_info VALUES (000670, 영풍, 2021-10-02)
# [2021-10-02 18:59] #0358 REPLACE INTO company_info VALUES (047400, 유니온머티리얼, 2021-10-02)
# [2021-10-02 18:59] #0359 REPLACE INTO company_info VALUES (005950, 이수화학, 2021-10-02)
# [2021-10-02 18:59] #0360 REPLACE INTO company_info VALUES (015020, 이스타코, 2021-10-02)
# [2021-10-02 18:59] #0361 REPLACE INTO company_info VALUES (074610, 이엔플러스, 2021-10-02)
# [2021-10-02 18:59] #0362 REPLACE INTO company_info VALUES (034590, 인천도시가스, 2021-10-02)
# [2021-10-02 18:59] #0363 REPLACE INTO company_info VALUES (000230, 일동홀딩스, 2021-10-02)
# [2021-10-02 18:59] #0364 REPLACE INTO company_info VALUES (013870, 지엠비코리아, 2021-10-02)
# [2021-10-02 18:59] #0365 REPLACE INTO company_info VALUES (323410, 카카오뱅크, 2021-10-02)
# [2021-10-02 18:59] #0366 REPLACE INTO company_info VALUES (007810, 코리아써키트, 2021-10-02)
# [2021-10-02 18:59] #0367 REPLACE INTO company_info VALUES (005420, 코스모화학, 2021-10-02)
# [2021-10-02 18:59] #0368 REPLACE INTO company_info VALUES (071950, 코아스, 2021-10-02)
# [2021-10-02 18:59] #0369 REPLACE INTO company_info VALUES (002020, 코오롱, 2021-10-02)
# [2021-10-02 18:59] #0370 REPLACE INTO company_info VALUES (144620, 코오롱머티리얼, 2021-10-02)
# [2021-10-02 18:59] #0371 REPLACE INTO company_info VALUES (138490, 코오롱플라스틱, 2021-10-02)
# [2021-10-02 18:59] #0372 REPLACE INTO company_info VALUES (192400, 쿠쿠홀딩스, 2021-10-02)
# [2021-10-02 18:59] #0373 REPLACE INTO company_info VALUES (015590, 큐로, 2021-10-02)
# [2021-10-02 18:59] #0374 REPLACE INTO company_info VALUES (259960, 크래프톤, 2021-10-02)
# [2021-10-02 18:59] #0375 REPLACE INTO company_info VALUES (009410, 태영건설, 2021-10-02)
# [2021-10-02 18:59] #0376 REPLACE INTO company_info VALUES (084870, 티비에이치글로벌, 2021-10-02)
# [2021-10-02 18:59] #0377 REPLACE INTO company_info VALUES (003670, 포스코케미칼, 2021-10-02)
# [2021-10-02 18:59] #0378 REPLACE INTO company_info VALUES (000080, 하이트진로, 2021-10-02)
# [2021-10-02 18:59] #0379 REPLACE INTO company_info VALUES (071050, 한국금융지주, 2021-10-02)
# [2021-10-02 18:59] #0380 REPLACE INTO company_info VALUES (006200, 한국전자홀딩스, 2021-10-02)
# [2021-10-02 18:59] #0381 REPLACE INTO company_info VALUES (023350, 한국종합기술, 2021-10-02)
# [2021-10-02 18:59] #0382 REPLACE INTO company_info VALUES (000970, 한국주철관공업, 2021-10-02)
# [2021-10-02 18:59] #0383 REPLACE INTO company_info VALUES (161890, 한국콜마, 2021-10-02)
# [2021-10-02 18:59] #0384 REPLACE INTO company_info VALUES (161390, 한국타이어앤테크놀로지, 2021-10-02)
# [2021-10-02 18:59] #0385 REPLACE INTO company_info VALUES (034830, 한국토지신탁, 2021-10-02)
# [2021-10-02 18:59] #0386 REPLACE INTO company_info VALUES (010100, 한국프랜지공업, 2021-10-02)
# [2021-10-02 18:59] #0387 REPLACE INTO company_info VALUES (018880, 한온시스템, 2021-10-02)
# [2021-10-02 18:59] #0388 REPLACE INTO company_info VALUES (009420, 한올바이오파마, 2021-10-02)
# [2021-10-02 18:59] #0389 REPLACE INTO company_info VALUES (097230, 한진중공업, 2021-10-02)
# [2021-10-02 18:59] #0390 REPLACE INTO company_info VALUES (101530, 해태제과식품, 2021-10-02)
# [2021-10-02 18:59] #0391 REPLACE INTO company_info VALUES (329180, 현대중공업, 2021-10-02)
# [2021-10-02 18:59] #0392 REPLACE INTO company_info VALUES (008770, 호텔신라, 2021-10-02)
# [2021-10-02 18:59] #0393 REPLACE INTO company_info VALUES (378850, 화승알앤에이, 2021-10-02)
# [2021-10-02 18:59] #0394 REPLACE INTO company_info VALUES (006060, 화승인더스트리, 2021-10-02)
# [2021-10-02 18:59] #0395 REPLACE INTO company_info VALUES (000850, 화천기공, 2021-10-02)
# [2021-10-02 18:59] #0396 REPLACE INTO company_info VALUES (016580, 환인제약, 2021-10-02)
# [2021-10-02 18:59] #0397 REPLACE INTO company_info VALUES (004800, 효성, 2021-10-02)
# [2021-10-02 18:59] #0398 REPLACE INTO company_info VALUES (298000, 효성화학, 2021-10-02)
# [2021-10-02 18:59] #0399 REPLACE INTO company_info VALUES (054620, APS홀딩스, 2021-10-02)
# [2021-10-02 18:59] #0400 REPLACE INTO company_info VALUES (065770, CS, 2021-10-02)
# [2021-10-02 18:59] #0401 REPLACE INTO company_info VALUES (083660, CSA 코스믹, 2021-10-02)
# [2021-10-02 18:59] #0402 REPLACE INTO company_info VALUES (036640, HRS, 2021-10-02)
# [2021-10-02 18:59] #0403 REPLACE INTO company_info VALUES (351320, IBKS제14호스팩, 2021-10-02)
# [2021-10-02 18:59] #0404 REPLACE INTO company_info VALUES (104200, NHN벅스, 2021-10-02)
# [2021-10-02 18:59] #0405 REPLACE INTO company_info VALUES (030190, NICE평가정보, 2021-10-02)
# [2021-10-02 18:59] #0406 REPLACE INTO company_info VALUES (327260, RF머트리얼즈, 2021-10-02)
# [2021-10-02 18:59] #0407 REPLACE INTO company_info VALUES (048550, SM C&C, 2021-10-02)
# [2021-10-02 18:59] #0408 REPLACE INTO company_info VALUES (317240, TS트릴리온, 2021-10-02)
# [2021-10-02 18:59] #0409 REPLACE INTO company_info VALUES (094480, 갤럭시아머니트리, 2021-10-02)
# [2021-10-02 18:59] #0410 REPLACE INTO company_info VALUES (223310, 경남제약헬스케어, 2021-10-02)
# [2021-10-02 18:59] #0411 REPLACE INTO company_info VALUES (098460, 고영, 2021-10-02)
# [2021-10-02 18:59] #0412 REPLACE INTO company_info VALUES (014200, 광림, 2021-10-02)
# [2021-10-02 18:59] #0413 REPLACE INTO company_info VALUES (006050, 국영지앤엠, 2021-10-02)
# [2021-10-02 18:59] #0414 REPLACE INTO company_info VALUES (307750, 국전약품, 2021-10-02)
# [2021-10-02 18:59] #0415 REPLACE INTO company_info VALUES (247660, 나노씨엠에스, 2021-10-02)
# [2021-10-02 18:59] #0416 REPLACE INTO company_info VALUES (039860, 나노엔텍, 2021-10-02)
# [2021-10-02 18:59] #0417 REPLACE INTO company_info VALUES (138610, 나이벡, 2021-10-02)
# [2021-10-02 18:59] #0418 REPLACE INTO company_info VALUES (091590, 남화토건, 2021-10-02)
# [2021-10-02 18:59] #0419 REPLACE INTO company_info VALUES (092730, 네오팜, 2021-10-02)
# [2021-10-02 18:59] #0420 REPLACE INTO company_info VALUES (348210, 넥스틴, 2021-10-02)
# [2021-10-02 18:59] #0421 REPLACE INTO company_info VALUES (217270, 넵튠, 2021-10-02)
# [2021-10-02 18:59] #0422 REPLACE INTO company_info VALUES (194700, 노바렉스, 2021-10-02)
# [2021-10-02 18:59] #0423 REPLACE INTO company_info VALUES (040160, 누리플렉스, 2021-10-02)
# [2021-10-02 18:59] #0424 REPLACE INTO company_info VALUES (104040, 대성파인텍, 2021-10-02)
# [2021-10-02 18:59] #0425 REPLACE INTO company_info VALUES (045390, 대아티아이, 2021-10-02)
# [2021-10-02 18:59] #0426 REPLACE INTO company_info VALUES (006580, 대양제지, 2021-10-02)
# [2021-10-02 18:59] #0427 REPLACE INTO company_info VALUES (096350, 대창솔루션, 2021-10-02)
# [2021-10-02 18:59] #0428 REPLACE INTO company_info VALUES (298540, 더네이쳐홀딩스, 2021-10-02)
# [2021-10-02 18:59] #0429 REPLACE INTO company_info VALUES (213420, 덕산네오룩스, 2021-10-02)
# [2021-10-02 18:59] #0430 REPLACE INTO company_info VALUES (100130, 동국S&C, 2021-10-02)
# [2021-10-02 18:59] #0431 REPLACE INTO company_info VALUES (005160, 동국산업, 2021-10-02)
# [2021-10-02 18:59] #0432 REPLACE INTO company_info VALUES (088130, 동아엘텍, 2021-10-02)
# [2021-10-02 18:59] #0433 REPLACE INTO company_info VALUES (217620, 디딤, 2021-10-02)
# [2021-10-02 18:59] #0434 REPLACE INTO company_info VALUES (214680, 디알텍, 2021-10-02)
# [2021-10-02 18:59] #0435 REPLACE INTO company_info VALUES (092070, 디엔에프, 2021-10-02)
# [2021-10-02 18:59] #0436 REPLACE INTO company_info VALUES (134580, 디엠티, 2021-10-02)
# [2021-10-02 18:59] #0437 REPLACE INTO company_info VALUES (039840, 디오, 2021-10-02)
# [2021-10-02 18:59] #0438 REPLACE INTO company_info VALUES (106520, 디지탈옵틱, 2021-10-02)
# [2021-10-02 18:59] #0439 REPLACE INTO company_info VALUES (131180, 딜리, 2021-10-02)
# [2021-10-02 18:59] #0440 REPLACE INTO company_info VALUES (315640, 딥노이드, 2021-10-02)
# [2021-10-02 18:59] #0441 REPLACE INTO company_info VALUES (038390, 레드캡투어, 2021-10-02)
# [2021-10-02 18:59] #0442 REPLACE INTO company_info VALUES (228850, 레이언스, 2021-10-02)
# [2021-10-02 18:59] #0443 REPLACE INTO company_info VALUES (215100, 로보로보, 2021-10-02)
# [2021-10-02 18:59] #0444 REPLACE INTO company_info VALUES (085370, 루트로닉, 2021-10-02)
# [2021-10-02 18:59] #0445 REPLACE INTO company_info VALUES (016100, 리더스코스메틱, 2021-10-02)
# [2021-10-02 18:59] #0446 REPLACE INTO company_info VALUES (029480, 릭스솔루션, 2021-10-02)
# [2021-10-02 18:59] #0447 REPLACE INTO company_info VALUES (005990, 매일홀딩스, 2021-10-02)
# [2021-10-02 18:59] #0448 REPLACE INTO company_info VALUES (377030, 맥스트, 2021-10-02)
# [2021-10-02 18:59] #0449 REPLACE INTO company_info VALUES (100590, 머큐리, 2021-10-02)
# [2021-10-02 18:59] #0450 REPLACE INTO company_info VALUES (014100, 메디앙스, 2021-10-02)
# [2021-10-02 18:59] #0451 REPLACE INTO company_info VALUES (065650, 메디프론, 2021-10-02)
# [2021-10-02 18:59] #0452 REPLACE INTO company_info VALUES (059210, 메타바이오메드, 2021-10-02)
# [2021-10-02 18:59] #0453 REPLACE INTO company_info VALUES (058110, 멕아이씨에스, 2021-10-02)
# [2021-10-02 18:59] #0454 REPLACE INTO company_info VALUES (096640, 멜파스, 2021-10-02)
# [2021-10-02 18:59] #0455 REPLACE INTO company_info VALUES (080160, 모두투어, 2021-10-02)
# [2021-10-02 18:59] #0456 REPLACE INTO company_info VALUES (001810, 무림SP, 2021-10-02)
# [2021-10-02 18:59] #0457 REPLACE INTO company_info VALUES (100790, 미래에셋벤처투자, 2021-10-02)
# [2021-10-02 18:59] #0458 REPLACE INTO company_info VALUES (208710, 바이오로그디바이스, 2021-10-02)
# [2021-10-02 18:59] #0459 REPLACE INTO company_info VALUES (323990, 박셀바이오, 2021-10-02)
# [2021-10-02 18:59] #0460 REPLACE INTO company_info VALUES (008470, 부스타, 2021-10-02)
# [2021-10-02 18:59] #0461 REPLACE INTO company_info VALUES (121800, 비덴트, 2021-10-02)
# [2021-10-02 18:59] #0462 REPLACE INTO company_info VALUES (032850, 비트컴퓨터, 2021-10-02)
# [2021-10-02 18:59] #0463 REPLACE INTO company_info VALUES (238200, 비피도, 2021-10-02)
# [2021-10-02 18:59] #0464 REPLACE INTO company_info VALUES (014970, 삼륭물산, 2021-10-02)
# [2021-10-02 18:59] #0465 REPLACE INTO company_info VALUES (225190, 삼양옵틱스, 2021-10-02)
# [2021-10-02 18:59] #0466 REPLACE INTO company_info VALUES (002290, 삼일기업공사, 2021-10-02)
# [2021-10-02 18:59] #0467 REPLACE INTO company_info VALUES (037460, 삼지전자, 2021-10-02)
# [2021-10-02 18:59] #0468 REPLACE INTO company_info VALUES (038500, 삼표시멘트, 2021-10-02)
# [2021-10-02 18:59] #0469 REPLACE INTO company_info VALUES (046390, 삼화네트웍스, 2021-10-02)
# [2021-10-02 18:59] #0470 REPLACE INTO company_info VALUES (027580, 상보, 2021-10-02)
# [2021-10-02 18:59] #0471 REPLACE INTO company_info VALUES (091580, 상신이디피, 2021-10-02)
# [2021-10-02 18:59] #0472 REPLACE INTO company_info VALUES (042940, 상지카일룸, 2021-10-02)
# [2021-10-02 18:59] #0473 REPLACE INTO company_info VALUES (043710, 서울리거, 2021-10-02)
# [2021-10-02 18:59] #0474 REPLACE INTO company_info VALUES (065710, 서호전기, 2021-10-02)
# [2021-10-02 18:59] #0475 REPLACE INTO company_info VALUES (015750, 성우하이텍, 2021-10-02)
# [2021-10-02 18:59] #0476 REPLACE INTO company_info VALUES (148150, 세경하이테크, 2021-10-02)
# [2021-10-02 18:59] #0477 REPLACE INTO company_info VALUES (017510, 세명전기, 2021-10-02)
# [2021-10-02 18:59] #0478 REPLACE INTO company_info VALUES (258830, 세종메디칼, 2021-10-02)
# [2021-10-02 18:59] #0479 REPLACE INTO company_info VALUES (108860, 셀바스AI, 2021-10-02)
# [2021-10-02 18:59] #0480 REPLACE INTO company_info VALUES (043100, 솔고바이오, 2021-10-02)
# [2021-10-02 18:59] #0481 REPLACE INTO company_info VALUES (154040, 솔루에타, 2021-10-02)
# [2021-10-02 18:59] #0482 REPLACE INTO company_info VALUES (357780, 솔브레인, 2021-10-02)
# [2021-10-02 18:59] #0483 REPLACE INTO company_info VALUES (236200, 슈프리마, 2021-10-02)
# [2021-10-02 18:59] #0484 REPLACE INTO company_info VALUES (253450, 스튜디오드래곤, 2021-10-02)
# [2021-10-02 18:59] #0485 REPLACE INTO company_info VALUES (269620, 시스웍, 2021-10-02)
# [2021-10-02 18:59] #0486 REPLACE INTO company_info VALUES (333050, 신한제6호스팩, 2021-10-02)
# [2021-10-02 18:59] #0487 REPLACE INTO company_info VALUES (099320, 쎄트렉아이, 2021-10-02)
# [2021-10-02 18:59] #0488 REPLACE INTO company_info VALUES (352480, 씨앤씨인터내셔널, 2021-10-02)
# [2021-10-02 18:59] #0489 REPLACE INTO company_info VALUES (352700, 씨앤투스성진, 2021-10-02)
# [2021-10-02 18:59] #0490 REPLACE INTO company_info VALUES (013990, 아가방컴퍼니, 2021-10-02)
# [2021-10-02 18:59] #0491 REPLACE INTO company_info VALUES (052710, 아모텍, 2021-10-02)
# [2021-10-02 18:59] #0492 REPLACE INTO company_info VALUES (092040, 아미코젠, 2021-10-02)
# [2021-10-02 18:59] #0493 REPLACE INTO company_info VALUES (101390, 아이엠, 2021-10-02)
# [2021-10-02 18:59] #0494 REPLACE INTO company_info VALUES (262840, 아이퀘스트, 2021-10-02)
# [2021-10-02 18:59] #0495 REPLACE INTO company_info VALUES (290740, 액트로, 2021-10-02)
# [2021-10-02 18:59] #0496 REPLACE INTO company_info VALUES (060230, 얍엑스, 2021-10-02)
# [2021-10-02 18:59] #0497 REPLACE INTO company_info VALUES (275630, 에스에스알, 2021-10-02)
# [2021-10-02 18:59] #0498 REPLACE INTO company_info VALUES (214310, 에스엘바이오닉스, 2021-10-02)
# [2021-10-02 18:59] #0499 REPLACE INTO company_info VALUES (237690, 에스티팜, 2021-10-02)
# [2021-10-02 18:59] #0500 REPLACE INTO company_info VALUES (109960, 에이프로젠 H&G, 2021-10-02)
# [2021-10-02 18:59] #0501 REPLACE INTO company_info VALUES (383310, 에코프로에이치엔, 2021-10-02)
# [2021-10-02 18:59] #0502 REPLACE INTO company_info VALUES (073540, 에프알텍, 2021-10-02)
# [2021-10-02 18:59] #0503 REPLACE INTO company_info VALUES (323230, 엠에프엠코리아, 2021-10-02)
# [2021-10-02 18:59] #0504 REPLACE INTO company_info VALUES (007530, 영신금속, 2021-10-02)
# [2021-10-02 18:59] #0505 REPLACE INTO company_info VALUES (036560, 영풍정밀, 2021-10-02)
# [2021-10-02 18:59] #0506 REPLACE INTO company_info VALUES (036000, 예림당, 2021-10-02)
# [2021-10-02 18:59] #0507 REPLACE INTO company_info VALUES (046120, 오르비텍, 2021-10-02)
# [2021-10-02 18:59] #0508 REPLACE INTO company_info VALUES (052420, 오성첨단소재, 2021-10-02)
# [2021-10-02 18:59] #0509 REPLACE INTO company_info VALUES (321820, 와이더플래닛, 2021-10-02)
# [2021-10-02 18:59] #0510 REPLACE INTO company_info VALUES (019210, 와이지-원, 2021-10-02)
# [2021-10-02 18:59] #0511 REPLACE INTO company_info VALUES (046970, 우리로, 2021-10-02)
# [2021-10-02 18:59] #0512 REPLACE INTO company_info VALUES (073560, 우리손에프앤지, 2021-10-02)
# [2021-10-02 18:59] #0513 REPLACE INTO company_info VALUES (101170, 우림기계, 2021-10-02)
# [2021-10-02 18:59] #0514 REPLACE INTO company_info VALUES (066590, 우수AMS, 2021-10-02)
# [2021-10-02 18:59] #0515 REPLACE INTO company_info VALUES (012620, 원일특강, 2021-10-02)
# [2021-10-02 18:59] #0516 REPLACE INTO company_info VALUES (192390, 윈하이텍, 2021-10-02)
# [2021-10-02 18:59] #0517 REPLACE INTO company_info VALUES (313760, 윌링스, 2021-10-02)
# [2021-10-02 18:59] #0518 REPLACE INTO company_info VALUES (086390, 유니테스트, 2021-10-02)
# [2021-10-02 18:59] #0519 REPLACE INTO company_info VALUES (206650, 유바이오로직스, 2021-10-02)
# [2021-10-02 18:59] #0520 REPLACE INTO company_info VALUES (367480, 유안타제8호스팩, 2021-10-02)
# [2021-10-02 18:59] #0521 REPLACE INTO company_info VALUES (067920, 이글루시큐리티, 2021-10-02)
# [2021-10-02 18:59] #0522 REPLACE INTO company_info VALUES (044960, 이글벳, 2021-10-02)
# [2021-10-02 18:59] #0523 REPLACE INTO company_info VALUES (088390, 이녹스, 2021-10-02)
# [2021-10-02 18:59] #0524 REPLACE INTO company_info VALUES (264850, 이랜시스, 2021-10-02)
# [2021-10-02 18:59] #0525 REPLACE INTO company_info VALUES (351330, 이삭엔지니어링, 2021-10-02)
# [2021-10-02 18:59] #0526 REPLACE INTO company_info VALUES (066980, 이엔코퍼레이션, 2021-10-02)
# [2021-10-02 18:59] #0527 REPLACE INTO company_info VALUES (099750, 이지케어텍, 2021-10-02)
# [2021-10-02 18:59] #0528 REPLACE INTO company_info VALUES (041830, 인바디, 2021-10-02)
# [2021-10-02 18:59] #0529 REPLACE INTO company_info VALUES (060150, 인선이엔티, 2021-10-02)
# [2021-10-02 18:59] #0530 REPLACE INTO company_info VALUES (048530, 인트론바이오, 2021-10-02)
# [2021-10-02 18:59] #0531 REPLACE INTO company_info VALUES (039290, 인포뱅크, 2021-10-02)
# [2021-10-02 18:59] #0532 REPLACE INTO company_info VALUES (110020, 전진바이오팜, 2021-10-02)
# [2021-10-02 18:59] #0533 REPLACE INTO company_info VALUES (208140, 정다운, 2021-10-02)
# [2021-10-02 18:59] #0534 REPLACE INTO company_info VALUES (022220, 정산애강, 2021-10-02)
# [2021-10-02 18:59] #0535 REPLACE INTO company_info VALUES (225220, 제놀루션, 2021-10-02)
# [2021-10-02 18:59] #0536 REPLACE INTO company_info VALUES (052670, 제일바이오, 2021-10-02)
# [2021-10-02 18:59] #0537 REPLACE INTO company_info VALUES (023440, 제일제강, 2021-10-02)
# [2021-10-02 18:59] #0538 REPLACE INTO company_info VALUES (041590, 젬백스지오, 2021-10-02)
# [2021-10-02 18:59] #0539 REPLACE INTO company_info VALUES (067000, 조이시티, 2021-10-02)
# [2021-10-02 18:59] #0540 REPLACE INTO company_info VALUES (078650, 지나인제약, 2021-10-02)
# [2021-10-02 18:59] #0541 REPLACE INTO company_info VALUES (043610, 지니뮤직, 2021-10-02)
# [2021-10-02 18:59] #0542 REPLACE INTO company_info VALUES (303030, 지니틱스, 2021-10-02)
# [2021-10-02 18:59] #0543 REPLACE INTO company_info VALUES (115450, 지트리비앤티, 2021-10-02)
# [2021-10-02 18:59] #0544 REPLACE INTO company_info VALUES (278280, 천보, 2021-10-02)
# [2021-10-02 18:59] #0545 REPLACE INTO company_info VALUES (025880, 케이씨피드, 2021-10-02)
# [2021-10-02 18:59] #0546 REPLACE INTO company_info VALUES (105330, 케이엔더블유, 2021-10-02)
# [2021-10-02 18:59] #0547 REPLACE INTO company_info VALUES (047770, 코데즈컴바인, 2021-10-02)
# [2021-10-02 18:59] #0548 REPLACE INTO company_info VALUES (078940, 코드네이처, 2021-10-02)
# [2021-10-02 18:59] #0549 REPLACE INTO company_info VALUES (290510, 코리아센터, 2021-10-02)
# [2021-10-02 18:59] #0550 REPLACE INTO company_info VALUES (190650, 코리아에셋투자증권, 2021-10-02)
# [2021-10-02 18:59] #0551 REPLACE INTO company_info VALUES (049430, 코메론, 2021-10-02)
# [2021-10-02 18:59] #0552 REPLACE INTO company_info VALUES (041960, 코미팜, 2021-10-02)
# [2021-10-02 18:59] #0553 REPLACE INTO company_info VALUES (045970, 코아시아, 2021-10-02)
# [2021-10-02 18:59] #0554 REPLACE INTO company_info VALUES (056360, 코위버, 2021-10-02)
# [2021-10-02 18:59] #0555 REPLACE INTO company_info VALUES (114120, 크루셜텍, 2021-10-02)
# [2021-10-02 18:59] #0556 REPLACE INTO company_info VALUES (083790, 크리스탈지노믹스, 2021-10-02)
# [2021-10-02 18:59] #0557 REPLACE INTO company_info VALUES (352770, 클리노믹스, 2021-10-02)
# [2021-10-02 18:59] #0558 REPLACE INTO company_info VALUES (023160, 태광, 2021-10-02)
# [2021-10-02 18:59] #0559 REPLACE INTO company_info VALUES (191420, 테고사이언스, 2021-10-02)
# ...
# [2021-10-02 18:59] #2277 REPLACE INTO company_info VALUES (013120, 동원개발, 2021-10-02)
# [2021-10-02 18:59] #2278 REPLACE INTO company_info VALUES (109860, 동일금속, 2021-10-02)
# [2021-10-02 18:59] #2279 REPLACE INTO company_info VALUES (025900, 동화기업, 2021-10-02)
# [2021-10-02 18:59] #2280 REPLACE INTO company_info VALUES (030350, 드래곤플라이, 2021-10-02)
# [2021-10-02 18:59] #2281 REPLACE INTO company_info VALUES (197140, 디지캡, 2021-10-02)
# [2021-10-02 18:59] #2282 REPLACE INTO company_info VALUES (317120, 라닉스, 2021-10-02)
# [2021-10-02 18:59] #2283 REPLACE INTO company_info VALUES (171120, 라이온켐텍, 2021-10-02)
# [2021-10-02 18:59] #2284 REPLACE INTO company_info VALUES (347700, 라이프시맨틱스, 2021-10-02)
# [2021-10-02 18:59] #2285 REPLACE INTO company_info VALUES (060300, 레드로버, 2021-10-02)
# [2021-10-02 18:59] #2286 REPLACE INTO company_info VALUES (108490, 로보티즈, 2021-10-02)
# [2021-10-02 18:59] #2287 REPLACE INTO company_info VALUES (071280, 로체시스템즈, 2021-10-02)
# [2021-10-02 18:59] #2288 REPLACE INTO company_info VALUES (058470, 리노공업, 2021-10-02)
# [2021-10-02 18:59] #2289 REPLACE INTO company_info VALUES (305090, 마이크로디지탈, 2021-10-02)
# [2021-10-02 18:59] #2290 REPLACE INTO company_info VALUES (093520, 매커스, 2021-10-02)
# [2021-10-02 18:59] #2291 REPLACE INTO company_info VALUES (041920, 메디아나, 2021-10-02)
# [2021-10-02 18:59] #2292 REPLACE INTO company_info VALUES (100030, 모바일리더, 2021-10-02)
# [2021-10-02 18:59] #2293 REPLACE INTO company_info VALUES (218150, 미래생명자원, 2021-10-02)
# [2021-10-02 18:59] #2294 REPLACE INTO company_info VALUES (046310, 백금T&A, 2021-10-02)
# [2021-10-02 18:59] #2295 REPLACE INTO company_info VALUES (006910, 보성파워텍, 2021-10-02)
# [2021-10-02 18:59] #2296 REPLACE INTO company_info VALUES (251630, 브이원텍, 2021-10-02)
# [2021-10-02 18:59] #2297 REPLACE INTO company_info VALUES (044480, 블루베리 NFT, 2021-10-02)
# [2021-10-02 18:59] #2298 REPLACE INTO company_info VALUES (148140, 비디아이, 2021-10-02)
# [2021-10-02 18:59] #2299 REPLACE INTO company_info VALUES (318410, 비비씨, 2021-10-02)
# [2021-10-02 18:59] #2300 REPLACE INTO company_info VALUES (200780, 비씨월드제약, 2021-10-02)
# [2021-10-02 18:59] #2301 REPLACE INTO company_info VALUES (141000, 비아트론, 2021-10-02)
# [2021-10-02 18:59] #2302 REPLACE INTO company_info VALUES (072950, 빛샘전자, 2021-10-02)
# [2021-10-02 18:59] #2303 REPLACE INTO company_info VALUES (122350, 삼기, 2021-10-02)
# [2021-10-02 18:59] #2304 REPLACE INTO company_info VALUES (065570, 삼영이엔씨, 2021-10-02)
# [2021-10-02 18:59] #2305 REPLACE INTO company_info VALUES (329560, 상상인이안제2호스팩, 2021-10-02)
# [2021-10-02 18:59] #2306 REPLACE INTO company_info VALUES (294630, 서남, 2021-10-02)
# [2021-10-02 18:59] #2307 REPLACE INTO company_info VALUES (189860, 서전기전, 2021-10-02)
# [2021-10-02 18:59] #2308 REPLACE INTO company_info VALUES (053060, 세동, 2021-10-02)
# [2021-10-02 18:59] #2309 REPLACE INTO company_info VALUES (067770, 세진티에스, 2021-10-02)
# [2021-10-02 18:59] #2310 REPLACE INTO company_info VALUES (068760, 셀트리온제약, 2021-10-02)
# [2021-10-02 18:59] #2311 REPLACE INTO company_info VALUES (091990, 셀트리온헬스케어, 2021-10-02)
# [2021-10-02 18:59] #2312 REPLACE INTO company_info VALUES (304100, 솔트룩스, 2021-10-02)
# [2021-10-02 18:59] #2313 REPLACE INTO company_info VALUES (086980, 쇼박스, 2021-10-02)
# [2021-10-02 18:59] #2314 REPLACE INTO company_info VALUES (058530, 슈펙스비앤피, 2021-10-02)
# [2021-10-02 18:59] #2315 REPLACE INTO company_info VALUES (317770, 슈프리마아이디, 2021-10-02)
# [2021-10-02 18:59] #2316 REPLACE INTO company_info VALUES (049830, 승일, 2021-10-02)
# [2021-10-02 18:59] #2317 REPLACE INTO company_info VALUES (215600, 신라젠, 2021-10-02)
# [2021-10-02 18:59] #2318 REPLACE INTO company_info VALUES (002800, 신신제약, 2021-10-02)
# [2021-10-02 18:59] #2319 REPLACE INTO company_info VALUES (160980, 싸이맥스, 2021-10-02)
# [2021-10-02 18:59] #2320 REPLACE INTO company_info VALUES (050890, 쏠리드, 2021-10-02)
# [2021-10-02 18:59] #2321 REPLACE INTO company_info VALUES (297090, 씨에스베어링, 2021-10-02)
# [2021-10-02 18:59] #2322 REPLACE INTO company_info VALUES (025980, 아난티, 2021-10-02)
# [2021-10-02 18:59] #2323 REPLACE INTO company_info VALUES (083930, 아바코, 2021-10-02)
# [2021-10-02 18:59] #2324 REPLACE INTO company_info VALUES (067390, 아스트, 2021-10-02)
# [2021-10-02 18:59] #2325 REPLACE INTO company_info VALUES (119830, 아이텍, 2021-10-02)
# [2021-10-02 18:59] #2326 REPLACE INTO company_info VALUES (297570, 알로이스, 2021-10-02)
# [2021-10-02 18:59] #2327 REPLACE INTO company_info VALUES (260660, 알리코제약, 2021-10-02)
# [2021-10-02 18:59] #2328 REPLACE INTO company_info VALUES (129890, 앱코, 2021-10-02)
# [2021-10-02 18:59] #2329 REPLACE INTO company_info VALUES (255440, 야스, 2021-10-02)
# [2021-10-02 18:59] #2330 REPLACE INTO company_info VALUES (030960, 양지사, 2021-10-02)
# [2021-10-02 18:59] #2331 REPLACE INTO company_info VALUES (042110, 에스씨디, 2021-10-02)
# [2021-10-02 18:59] #2332 REPLACE INTO company_info VALUES (109610, 에스와이, 2021-10-02)
# [2021-10-02 18:59] #2333 REPLACE INTO company_info VALUES (069510, 에스텍, 2021-10-02)
# [2021-10-02 18:59] #2334 REPLACE INTO company_info VALUES (050760, 에스폴리텍, 2021-10-02)
# [2021-10-02 18:59] #2335 REPLACE INTO company_info VALUES (317830, 에스피시스템스, 2021-10-02)
# [2021-10-02 18:59] #2336 REPLACE INTO company_info VALUES (203400, 에이비온, 2021-10-02)
# [2021-10-02 18:59] #2337 REPLACE INTO company_info VALUES (312610, 에이에프더블류, 2021-10-02)
# [2021-10-02 18:59] #2338 REPLACE INTO company_info VALUES (072990, 에이치시티, 2021-10-02)
# [2021-10-02 18:59] #2339 REPLACE INTO company_info VALUES (028300, 에이치엘비, 2021-10-02)
# [2021-10-02 18:59] #2340 REPLACE INTO company_info VALUES (067630, 에이치엘비생명과학, 2021-10-02)
# [2021-10-02 18:59] #2341 REPLACE INTO company_info VALUES (043220, 에이치엘비파워, 2021-10-02)
# [2021-10-02 18:59] #2342 REPLACE INTO company_info VALUES (357230, 에이치피오, 2021-10-02)
# [2021-10-02 18:59] #2343 REPLACE INTO company_info VALUES (230980, 에이트원, 2021-10-02)
# [2021-10-02 18:59] #2344 REPLACE INTO company_info VALUES (064090, 에프앤리퍼블릭, 2021-10-02)
# [2021-10-02 18:59] #2345 REPLACE INTO company_info VALUES (036810, 에프에스티, 2021-10-02)
# [2021-10-02 18:59] #2346 REPLACE INTO company_info VALUES (054940, 엑사이엔씨, 2021-10-02)
# [2021-10-02 18:59] #2347 REPLACE INTO company_info VALUES (354200, 엔젠바이오, 2021-10-02)
# [2021-10-02 18:59] #2348 REPLACE INTO company_info VALUES (291230, 엔피, 2021-10-02)
# [2021-10-02 18:59] #2349 REPLACE INTO company_info VALUES (048830, 엔피케이, 2021-10-02)
# [2021-10-02 18:59] #2350 REPLACE INTO company_info VALUES (170920, 엘티씨, 2021-10-02)
# [2021-10-02 18:59] #2351 REPLACE INTO company_info VALUES (033310, 엠투엔, 2021-10-02)
# [2021-10-02 18:59] #2352 REPLACE INTO company_info VALUES (143540, 영우디에스피, 2021-10-02)
# [2021-10-02 18:59] #2353 REPLACE INTO company_info VALUES (250930, 예선테크, 2021-10-02)
# [2021-10-02 18:59] #2354 REPLACE INTO company_info VALUES (039830, 오로라, 2021-10-02)
# [2021-10-02 18:59] #2355 REPLACE INTO company_info VALUES (053980, 오상자이엘, 2021-10-02)
# [2021-10-02 18:59] #2356 REPLACE INTO company_info VALUES (039200, 오스코텍, 2021-10-02)
# [2021-10-02 18:59] #2357 REPLACE INTO company_info VALUES (173130, 오파스넷, 2021-10-02)
# [2021-10-02 18:59] #2358 REPLACE INTO company_info VALUES (226950, 올릭스, 2021-10-02)
# [2021-10-02 18:59] #2359 REPLACE INTO company_info VALUES (057540, 옴니시스템, 2021-10-02)
# [2021-10-02 18:59] #2360 REPLACE INTO company_info VALUES (153710, 옵티팜, 2021-10-02)
# [2021-10-02 18:59] #2361 REPLACE INTO company_info VALUES (273640, 와이엠텍, 2021-10-02)
# [2021-10-02 18:59] #2362 REPLACE INTO company_info VALUES (215360, 우리산업, 2021-10-02)
# [2021-10-02 18:59] #2363 REPLACE INTO company_info VALUES (046940, 우원개발, 2021-10-02)
# [2021-10-02 18:59] #2364 REPLACE INTO company_info VALUES (215380, 우정바이오, 2021-10-02)
# [2021-10-02 18:59] #2365 REPLACE INTO company_info VALUES (018620, 우진비앤지, 2021-10-02)
# [2021-10-02 18:59] #2366 REPLACE INTO company_info VALUES (307280, 원바이오젠, 2021-10-02)
# [2021-10-02 18:59] #2367 REPLACE INTO company_info VALUES (032940, 원익, 2021-10-02)
# [2021-10-02 18:59] #2368 REPLACE INTO company_info VALUES (014190, 원익큐브, 2021-10-02)
# [2021-10-02 18:59] #2369 REPLACE INTO company_info VALUES (131390, 원익피앤이, 2021-10-02)
# [2021-10-02 18:59] #2370 REPLACE INTO company_info VALUES (038620, 위즈코프, 2021-10-02)
# [2021-10-02 18:59] #2371 REPLACE INTO company_info VALUES (097800, 윈팩, 2021-10-02)
# [2021-10-02 18:59] #2372 REPLACE INTO company_info VALUES (032620, 유비케어, 2021-10-02)
# [2021-10-02 18:59] #2373 REPLACE INTO company_info VALUES (056090, 유앤아이, 2021-10-02)
# [2021-10-02 18:59] #2374 REPLACE INTO company_info VALUES (331380, 유진스팩5호, 2021-10-02)
# [2021-10-02 18:59] #2375 REPLACE INTO company_info VALUES (302430, 이노메트리, 2021-10-02)
# [2021-10-02 18:59] #2376 REPLACE INTO company_info VALUES (246960, 이노테라피, 2021-10-02)
# [2021-10-02 18:59] #2377 REPLACE INTO company_info VALUES (164060, 이루다, 2021-10-02)
# [2021-10-02 18:59] #2378 REPLACE INTO company_info VALUES (131400, 이브이첨단소재, 2021-10-02)
# [2021-10-02 18:59] #2379 REPLACE INTO company_info VALUES (067010, 이씨에스, 2021-10-02)
# [2021-10-02 18:59] #2380 REPLACE INTO company_info VALUES (101360, 이엔드디, 2021-10-02)
# [2021-10-02 18:59] #2381 REPLACE INTO company_info VALUES (039030, 이오테크닉스, 2021-10-02)
# [2021-10-02 18:59] #2382 REPLACE INTO company_info VALUES (035810, 이지홀딩스, 2021-10-02)
# [2021-10-02 18:59] #2383 REPLACE INTO company_info VALUES (352940, 인바이오, 2021-10-02)
# [2021-10-02 18:59] #2384 REPLACE INTO company_info VALUES (119610, 인터로조, 2021-10-02)
# [2021-10-02 18:59] #2385 REPLACE INTO company_info VALUES (051370, 인터플렉스, 2021-10-02)
# [2021-10-02 18:59] #2386 REPLACE INTO company_info VALUES (101930, 인화정공, 2021-10-02)
# [2021-10-02 18:59] #2387 REPLACE INTO company_info VALUES (219550, 자안코스메틱, 2021-10-02)
# [2021-10-02 18:59] #2388 REPLACE INTO company_info VALUES (043910, 자연과환경, 2021-10-02)
# [2021-10-02 18:59] #2389 REPLACE INTO company_info VALUES (090470, 제이스텍, 2021-10-02)
# [2021-10-02 18:59] #2390 REPLACE INTO company_info VALUES (126880, 제이엔케이히터, 2021-10-02)
# [2021-10-02 18:59] #2391 REPLACE INTO company_info VALUES (038010, 제일테크노스, 2021-10-02)
# [2021-10-02 18:59] #2392 REPLACE INTO company_info VALUES (216080, 제테마, 2021-10-02)
# [2021-10-02 18:59] #2393 REPLACE INTO company_info VALUES (228760, 지노믹트리, 2021-10-02)
# [2021-10-02 18:59] #2394 REPLACE INTO company_info VALUES (051160, 지어소프트, 2021-10-02)
# [2021-10-02 18:59] #2395 REPLACE INTO company_info VALUES (053050, 지에스이, 2021-10-02)
# [2021-10-02 18:59] #2396 REPLACE INTO company_info VALUES (007370, 진양제약, 2021-10-02)
# [2021-10-02 18:59] #2397 REPLACE INTO company_info VALUES (085660, 차바이오텍, 2021-10-02)
# [2021-10-02 18:59] #2398 REPLACE INTO company_info VALUES (311690, 천랩, 2021-10-02)
# [2021-10-02 18:59] #2399 REPLACE INTO company_info VALUES (096240, 청담러닝, 2021-10-02)
# [2021-10-02 18:59] #2400 REPLACE INTO company_info VALUES (180400, 캔서롭, 2021-10-02)
# [2021-10-02 18:59] #2401 REPLACE INTO company_info VALUES (317030, 케이비17호스팩, 2021-10-02)
# [2021-10-02 18:59] #2402 REPLACE INTO company_info VALUES (039420, 케이엘넷, 2021-10-02)
# [2021-10-02 18:59] #2403 REPLACE INTO company_info VALUES (032500, 케이엠더블유, 2021-10-02)
# [2021-10-02 18:59] #2404 REPLACE INTO company_info VALUES (036030, 케이티알파, 2021-10-02)
# [2021-10-02 18:59] #2405 REPLACE INTO company_info VALUES (052400, 코나아이, 2021-10-02)
# [2021-10-02 18:59] #2406 REPLACE INTO company_info VALUES (104540, 코렌텍, 2021-10-02)
# [2021-10-02 18:59] #2407 REPLACE INTO company_info VALUES (027050, 코리아나, 2021-10-02)
# [2021-10-02 18:59] #2408 REPLACE INTO company_info VALUES (950160, 코오롱티슈진, 2021-10-02)
# [2021-10-02 18:59] #2409 REPLACE INTO company_info VALUES (282880, 코윈테크, 2021-10-02)
# [2021-10-02 18:59] #2410 REPLACE INTO company_info VALUES (015710, 코콤, 2021-10-02)
# [2021-10-02 18:59] #2411 REPLACE INTO company_info VALUES (317690, 퀀타매트릭스, 2021-10-02)
# [2021-10-02 18:59] #2412 REPLACE INTO company_info VALUES (043090, 큐브앤컴퍼니, 2021-10-02)
# [2021-10-02 18:59] #2413 REPLACE INTO company_info VALUES (066310, 큐에스아이, 2021-10-02)
# [2021-10-02 18:59] #2414 REPLACE INTO company_info VALUES (036170, 클라우드에어, 2021-10-02)
# [2021-10-02 18:59] #2415 REPLACE INTO company_info VALUES (054450, 텔레칩스, 2021-10-02)
# [2021-10-02 18:59] #2416 REPLACE INTO company_info VALUES (091440, 텔레필드, 2021-10-02)
# [2021-10-02 18:59] #2417 REPLACE INTO company_info VALUES (104480, 티케이케미칼, 2021-10-02)
# [2021-10-02 18:59] #2418 REPLACE INTO company_info VALUES (081150, 티플랙스, 2021-10-02)
# [2021-10-02 18:59] #2419 REPLACE INTO company_info VALUES (170790, 파이오링크, 2021-10-02)
# [2021-10-02 18:59] #2420 REPLACE INTO company_info VALUES (049120, 파인디앤씨, 2021-10-02)
# [2021-10-02 18:59] #2421 REPLACE INTO company_info VALUES (009520, 포스코엠텍, 2021-10-02)
# [2021-10-02 18:59] #2422 REPLACE INTO company_info VALUES (189690, 포시에스, 2021-10-02)
# [2021-10-02 18:59] #2423 REPLACE INTO company_info VALUES (094940, 푸른기술, 2021-10-02)
# [2021-10-02 18:59] #2424 REPLACE INTO company_info VALUES (035200, 프럼파스트, 2021-10-02)
# [2021-10-02 18:59] #2425 REPLACE INTO company_info VALUES (334970, 프레스티지바이오로직스, 2021-10-02)
# [2021-10-02 18:59] #2426 REPLACE INTO company_info VALUES (300080, 플리토, 2021-10-02)
# [2021-10-02 18:59] #2427 REPLACE INTO company_info VALUES (136480, 하림, 2021-10-02)
# [2021-10-02 18:59] #2428 REPLACE INTO company_info VALUES (013030, 하이록코리아, 2021-10-02)
# [2021-10-02 18:59] #2429 REPLACE INTO company_info VALUES (126700, 하이비젼시스템, 2021-10-02)
# [2021-10-02 18:59] #2430 REPLACE INTO company_info VALUES (066130, 하츠, 2021-10-02)
# [2021-10-02 18:59] #2431 REPLACE INTO company_info VALUES (034950, 한국기업평가, 2021-10-02)
# [2021-10-02 18:59] #2432 REPLACE INTO company_info VALUES (017890, 한국알콜, 2021-10-02)
# [2021-10-02 18:59] #2433 REPLACE INTO company_info VALUES (063570, 한국전자금융, 2021-10-02)
# [2021-10-02 18:59] #2434 REPLACE INTO company_info VALUES (039740, 한국정보공학, 2021-10-02)
# [2021-10-02 18:59] #2435 REPLACE INTO company_info VALUES (052600, 한네트, 2021-10-02)
# [2021-10-02 18:59] #2436 REPLACE INTO company_info VALUES (092460, 한라IMS, 2021-10-02)
# [2021-10-02 18:59] #2437 REPLACE INTO company_info VALUES (042520, 한스바이오메드, 2021-10-02)
# [2021-10-02 18:59] #2438 REPLACE INTO company_info VALUES (054920, 한컴위드, 2021-10-02)
# [2021-10-02 18:59] #2439 REPLACE INTO company_info VALUES (016790, 현대사료, 2021-10-02)
# [2021-10-02 18:59] #2440 REPLACE INTO company_info VALUES (060560, 홈센타홀딩스, 2021-10-02)
# [2021-10-02 18:59] #2441 REPLACE INTO company_info VALUES (028080, 휴맥스홀딩스, 2021-10-02)
# [2021-10-02 18:59] #2442 REPLACE INTO company_info VALUES (238490, 힘스, 2021-10-02)
# [2021-10-02 18:59] #2443 REPLACE INTO company_info VALUES (288490, 나라소프트, 2021-10-02)
# [2021-10-02 18:59] #2444 REPLACE INTO company_info VALUES (176750, 듀켐바이오, 2021-10-02)
# [2021-10-02 18:59] #2445 REPLACE INTO company_info VALUES (200350, 래몽래인, 2021-10-02)
# [2021-10-02 18:59] #2446 REPLACE INTO company_info VALUES (236340, 메디젠휴먼케어, 2021-10-02)
# [2021-10-02 18:59] #2447 REPLACE INTO company_info VALUES (224810, 엄지하우스, 2021-10-02)
# [2021-10-02 18:59] #2448 REPLACE INTO company_info VALUES (224020, 에스케이씨에스, 2021-10-02)
# [2021-10-02 18:59] #2449 REPLACE INTO company_info VALUES (207490, 에이펙스인텍, 2021-10-02)
# [2021-10-02 18:59] #2450 REPLACE INTO company_info VALUES (329020, 오션스톤, 2021-10-02)
# [2021-10-02 18:59] #2451 REPLACE INTO company_info VALUES (216280, 원텍, 2021-10-02)
# [2021-10-02 18:59] #2452 REPLACE INTO company_info VALUES (122830, 원포유, 2021-10-02)
# [2021-10-02 18:59] #2453 REPLACE INTO company_info VALUES (140660, 위월드, 2021-10-02)
# [2021-10-02 18:59] #2454 REPLACE INTO company_info VALUES (232530, 이엠티, 2021-10-02)
# [2021-10-02 18:59] #2455 REPLACE INTO company_info VALUES (299480, 지앤이헬스케어, 2021-10-02)
# [2021-10-02 18:59] #2456 REPLACE INTO company_info VALUES (327970, 케어룸의료산업, 2021-10-02)
# [2021-10-02 18:59] #2457 REPLACE INTO company_info VALUES (189350, 코셋, 2021-10-02)
# [2021-10-02 18:59] #2458 REPLACE INTO company_info VALUES (318660, 타임기술, 2021-10-02)
# [2021-10-02 18:59] #2459 REPLACE INTO company_info VALUES (199800, 툴젠, 2021-10-02)
# [2021-10-02 18:59] #2460 REPLACE INTO company_info VALUES (222670, 플럼라인생명과학, 2021-10-02)
# [2021-10-02 18:59] #2461 REPLACE INTO company_info VALUES (331660, 한국미라클피플사, 2021-10-02)
# [2021-10-02 18:59] #2462 REPLACE INTO company_info VALUES (212310, 휴벡셀, 2021-10-02)
# Waiting for next update (2021-10-03 17:00) ...

# %% [markdown]
# - 시세 조회 API : Investar 패키지의 Analyzer 모듈에 포함. MarketDB 클래스의 get_daily_price() 메서드

# %%
import pandas as pd
#from bs4 import BeautifulSoup
#import urllib
#from urllib.request import urlopen
import pymysql
#import time
#import pandas.io.sql as sql
from datetime import datetime
#from threading import Timer
#import matplotlib.pyplot as plt

class MarketDB:
    def __init__(self):
        """생성자: MariaDB 연결 및 종목코드 딕셔너리 생성"""
        self.conn = pymysql.connect(host='localhost', user='root', password='kjs34590', db='Investar', charset='utf8')
        self.codes = dict()
        self.getCompanyInfo()
        
    def __del__(self):
        """소멸자: MariaDB 연결 해제"""
        self.conn.close()

    def getCompanyInfo(self):
        """company_info 테이블에서 읽어와서 companyData와 codes에 저장"""
        sql = "SELECT * FROM company_info"
        companyInfo = pd.read_sql(sql, self.conn)
        for idx in range(len(companyInfo)):
            self.codes[companyInfo['code'].values[idx]] = companyInfo['company'].values[idx]

    def getDailyPrice(self, code, startDate, endDate):
        """daily_price 테이블에서 읽어와서 데이터프레임으로 반환"""
        sql = "SELECT * FROM daily_price WHERE code = '{}' and date >= '{}' and date <= '{}'".format(code, startDate, endDate)
        df = pd.read_sql(sql, self.conn)
        df.index = df['date']
        return df

# %%
import pandas as pd
import pymysql
from datetime import datetime
from datetime import timedelta
import re

class MarketDB:
    def __init__(self):
        """생성자: MariaDB 연결 및 종목코드 딕셔너리 생성"""
        self.conn = pymysql.connect(host='localhost', user='root', 
            password='kjs34590', db='Investar', charset='utf8')
        self.codes = {}
        self.get_comp_info()
        
    def __del__(self):
        """소멸자: MariaDB 연결 해제"""
        self.conn.close()

    def get_comp_info(self):
        """company_info 테이블에서 읽어와서 codes에 저장"""
        sql = "SELECT * FROM company_info"
        krx = pd.read_sql(sql, self.conn)
        for idx in range(len(krx)):
            self.codes[krx['code'].values[idx]] = krx['company'].values[idx]

    def get_daily_price(self, code, start_date=None, end_date=None):
        """KRX 종목의 일별 시세를 데이터프레임 형태로 반환
            - code       : KRX 종목코드('005930') 또는 상장기업명('삼성전자')
            - start_date : 조회 시작일('2020-01-01'), 미입력 시 1년 전 오늘
            - end_date   : 조회 종료일('2020-12-31'), 미입력 시 오늘 날짜
        """
        if start_date is None:
            one_year_ago = datetime.today() - timedelta(days=365)
            start_date = one_year_ago.strftime('%Y-%m-%d')
            print("start_date is initialized to '{}'".format(start_date))
        else:
            start_lst = re.split('\D+', start_date)
            if start_lst[0] == '':
                start_lst = start_lst[1:]
            start_year = int(start_lst[0])
            start_month = int(start_lst[1])
            start_day = int(start_lst[2])
            if start_year < 1900 or start_year > 2200:
                print(f"ValueError: start_year({start_year:d}) is wrong.")
                return
            if start_month < 1 or start_month > 12:
                print(f"ValueError: start_month({start_month:d}) is wrong.")
                return
            if start_day < 1 or start_day > 31:
                print(f"ValueError: start_day({start_day:d}) is wrong.")
                return
            start_date=f"{start_year:04d}-{start_month:02d}-{start_day:02d}"

        if end_date is None:
            end_date = datetime.today().strftime('%Y-%m-%d')
            print("end_date is initialized to '{}'".format(end_date))
        else:
            end_lst = re.split('\D+', end_date)
            if end_lst[0] == '':
                end_lst = end_lst[1:] 
            end_year = int(end_lst[0])
            end_month = int(end_lst[1])
            end_day = int(end_lst[2])
            if end_year < 1800 or end_year > 2200:
                print(f"ValueError: end_year({end_year:d}) is wrong.")
                return
            if end_month < 1 or end_month > 12:
                print(f"ValueError: end_month({end_month:d}) is wrong.")
                return
            if end_day < 1 or end_day > 31:
                print(f"ValueError: end_day({end_day:d}) is wrong.")
                return
            end_date = f"{end_year:04d}-{end_month:02d}-{end_day:02d}"
         
        codes_keys = list(self.codes.keys())
        codes_values = list(self.codes.values())

        if code in codes_keys:
            pass
        elif code in codes_values:
            idx = codes_values.index(code)
            code = codes_keys[idx]
        else:
            print(f"ValueError: Code({code}) doesn't exist.")
        sql = f"SELECT * FROM daily_price WHERE code = '{code}'"\
            f" and date >= '{start_date}' and date <= '{end_date}'"
        df = pd.read_sql(sql, self.conn)
        df.index = df['date']
        return df

# %% [markdown]
# - 네이버 시세 데이터베이스 삼성전자 데이터

# %%
import matplotlib.pyplot as plt
import Analyzer
# from Investar import Analyzer

mk = Analyzer.MarketDB()
# mk = MarketDB()
df = mk.get_daily_price('005930', '2017-07-10', '2018-06-30')

plt.figure(figsize=(9,6))
plt.subplot(2, 1, 1)
plt.title('Samsung Electronics (Investar Data)')
plt.plot(df.index, df['close'], 'c', label='Close')
plt.legend(loc='best')
plt.subplot(2, 1, 2)
plt.plot(df.index, df['volume'], 'g', label='Volume')
plt.legend(loc='best')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-41-e4ee6f3c65af> in <module>
#       3 # from Investar import Analyzer
#       4
# ----> 5 mk = Analyzer.MarketDB()
#       6 # mk = MarketDB()
#       7 df = mk.get_daily_price('005930', '2017-07-10', '2018-06-30')
#
# C:\DATA_WORKS\PYTHON_WORKS\python_stock\Analyzer.py in __init__(self)
#       8     def __init__(self):
#       9         """생성자: MariaDB 연결 및 종목코드 딕셔너리 생성"""
# ---> 10         self.conn = pymysql.connect(host='localhost', user='root',
#      11             password='myPa$$word', db='INVESTAR', charset='utf8')
#      12         self.codes = {}
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in __init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     351             self._sock = None
#     352         else:
# --> 353             self.connect()
#     354
#     355     def __enter__(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     631
#     632             self._get_server_information()
# --> 633             self._request_authentication()
#     634
#     635             if self.sql_mode is not None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in _request_authentication(self)
#     905
#     906         self.write_packet(data)
# --> 907         auth_packet = self._read_packet()
#     908
#     909         # if authentication method isn't accepted the first byte
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     723             if self._result is not None and self._result.unbuffered_active is True:
#     724                 self._result.unbuffered_active = False
# --> 725             packet.raise_for_error()
#     726         return packet
#     727
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\protocol.py in raise_for_error(self)
#     219         if DEBUG:
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#     223     def dump(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     141     if errorclass is None:
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# OperationalError: (1045, "Access denied for user 'root'@'localhost' (using password: YES)")
# Exception in thread Thread-9:
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py", line 756, in _write_bytes
#     self._sock.sendall(data)
# ConnectionAbortedError: [WinError 10053] 현재 연결은 사용자의 호스트 시스템의 소프트웨어의 의해 중단되었습니다
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py", line 1681, in execute
#     cur.execute(*args, **kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py", line 148, in execute
#     result = self._query(query)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py", line 310, in _query
#     conn.query(q)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py", line 547, in query
#     self._execute_command(COMMAND.COM_QUERY, sql)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py", line 814, in _execute_command
#     self._write_bytes(packet)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py", line 759, in _write_bytes
#     raise err.OperationalError(
# pymysql.err.OperationalError: (2006, "MySQL server has gone away (ConnectionAbortedError(10053, '현재 연결은 사용자의 호스트 시스템의 소프트웨어의 의해 중단되었습니다', None, 10053, None))")
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py", line 1685, in execute
#     self.con.rollback()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py", line 479, in rollback
#     self._execute_command(COMMAND.COM_QUERY, "ROLLBACK")
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py", line 793, in _execute_command
#     raise err.InterfaceError(0, "")
# pymysql.err.InterfaceError: (0, '')
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 1254, in run
#     self.function(*self.args, **self.kwargs)
#   File "<ipython-input-32-e97d4402dfd0>", line 138, in execute_daily
#   File "<ipython-input-32-e97d4402dfd0>", line 57, in update_comp_info
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py", line 483, in read_sql
#     return pandas_sql.read_query(
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py", line 1727, in read_query
#     cursor = self.execute(*args)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py", line 1690, in execute
#     raise ex from inner_exc
# pandas.io.sql.DatabaseError: Execution failed on sql: SELECT * FROM company_info
# (2006, "MySQL server has gone away (ConnectionAbortedError(10053, '현재 연결은 사용자의 호스트 시스템의 소프트웨어의 의해 중단되었습니다', None, 10053, None))")
# unable to rollback
